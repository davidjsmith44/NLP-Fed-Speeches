# %%
# testing import
import pickle
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
# %config InlineBackend.figure_format='retina'
import seaborn as sns
sns.set(style='white', palette='muted', color_codes = True)

# %%
pwd
# Out:
# '/Users/davidsmith/Documents/Galvanize/Capstone/data'

# %%
zeros = pickle.load(open("zero_rates", "rb" ) )

# %%
zeros.head()
# Out:
#             three_m   six_m   one_y   two_y  three_y   five_y  seven_y  \
# Date
# 2006-01-03   0.0416  0.0440  0.0438  0.0434   0.0430  0.04299  0.04321
# 2006-01-04   0.0419  0.0437  0.0435  0.0431   0.0428  0.04279  0.04312
# 2006-01-05   0.0420  0.0437  0.0436  0.0432   0.0429  0.04289  0.04312
# 2006-01-06   0.0422  0.0439  0.0438  0.0436   0.0432  0.04319  0.04331
# 2006-01-09   0.0423  0.0440  0.0439  0.0436   0.0432  0.04319  0.04341
#
#               ten_y
# Date
# 2006-01-03  0.04378
# 2006-01-04  0.04368
# 2006-01-05  0.04368
# 2006-01-06  0.04387
# 2006-01-09  0.04386

# %%
plt.plot(zeros)

# %%
zeros.corr()
# Out:
#           three_m     six_m     one_y     two_y   three_y    five_y   seven_y  \
# three_m  1.000000  0.998242  0.994855  0.984476  0.968359  0.919127  0.853216
# six_m    0.998242  1.000000  0.998577  0.989907  0.974549  0.925918  0.859246
# one_y    0.994855  0.998577  1.000000  0.994808  0.981315  0.933510  0.866210
# two_y    0.984476  0.989907  0.994808  1.000000  0.994906  0.958114  0.897331
# three_y  0.968359  0.974549  0.981315  0.994906  1.000000  0.980003  0.931248
# five_y   0.919127  0.925918  0.933510  0.958114  0.980003  1.000000  0.983932
# seven_y  0.853216  0.859246  0.866210  0.897331  0.931248  0.983932  1.000000
# ten_y    0.765736  0.770972  0.775006  0.805478  0.845369  0.926978  0.975725
#
#             ten_y
# three_m  0.765736
# six_m    0.770972
# one_y    0.775006
# two_y    0.805478
# three_y  0.845369
# five_y   0.926978
# seven_y  0.975725
# ten_y    1.000000

# %%
### The zeros are highly correlated. Lets see what the rank is for the matrix
my_rank = np.linalg.matrix_rank(zeros)
my_rank
# Out:
# 8

# %%
## OK the zero rates (spot rates) have to correct rank

# %%
ylds = pickle.load(open('interest_rate_data', 'rb'))

# %%
ylds.head()
# Out:
#             three_m   six_m   one_y   two_y  three_y  five_y  seven_y   ten_y
# Date
# 2006-01-03   0.0416  0.0440  0.0438  0.0434   0.0430  0.0430   0.0432  0.0437
# 2006-01-04   0.0419  0.0437  0.0435  0.0431   0.0428  0.0428   0.0431  0.0436
# 2006-01-05   0.0420  0.0437  0.0436  0.0432   0.0429  0.0429   0.0431  0.0436
# 2006-01-06   0.0422  0.0439  0.0438  0.0436   0.0432  0.0432   0.0433  0.0438
# 2006-01-09   0.0423  0.0440  0.0439  0.0436   0.0432  0.0432   0.0434  0.0438

# %%
plt.plot(ylds)

# %%
ylds.corr()
# Out:
#           three_m     six_m     one_y     two_y   three_y    five_y   seven_y  \
# three_m  1.000000  0.998242  0.994855  0.984638  0.968725  0.922311  0.863613
# six_m    0.998242  1.000000  0.998577  0.990036  0.974870  0.928988  0.869544
# one_y    0.994855  0.998577  1.000000  0.994884  0.981565  0.936423  0.876321
# two_y    0.984638  0.990036  0.994884  1.000000  0.994985  0.960394  0.906274
# three_y  0.968725  0.974870  0.981565  0.994985  1.000000  0.981423  0.938308
# five_y   0.922311  0.928988  0.936423  0.960394  0.981423  1.000000  0.986137
# seven_y  0.863613  0.869544  0.876321  0.906274  0.938308  0.986137  1.000000
# ten_y    0.789142  0.794289  0.798325  0.827754  0.865152  0.938403  0.979950
#
#             ten_y
# three_m  0.789142
# six_m    0.794289
# one_y    0.798325
# two_y    0.827754
# three_y  0.865152
# five_y   0.938403
# seven_y  0.979950
# ten_y    1.000000

# %%
# now testing the rank
np.linalg.matrix_rank(ylds)
# Out:
# 8

# %%
## OK the rank looks good for both yields and rates

# %%
forwards= pickle.load(open('forward_rates', 'rb'))

# %%
col_names = forwards.columns
col_names
# Out:
# Index(['six_m', 'one_y', 'two_y', 'three_y', 'five_y', 'seven_y', 'ten_y'], dtype='object')

# %%
plt.plot(forwards)
plt.legend(col_names)

# %%
forwards.corr()
# Out:
#             six_m     one_y     two_y   three_y    five_y   seven_y     ten_y
# six_m    1.000000  0.998577  0.966265  0.895487  0.720743  0.457908  0.379434
# one_y    0.998577  1.000000  0.975178  0.906434  0.729003  0.461338  0.375285
# two_y    0.966265  0.975178  1.000000  0.966884  0.813416  0.552815  0.418880
# three_y  0.895487  0.906434  0.966884  1.000000  0.916214  0.702267  0.536619
# five_y   0.720743  0.729003  0.813416  0.916214  1.000000  0.911448  0.776689
# seven_y  0.457908  0.461338  0.552815  0.702267  0.911448  1.000000  0.917525
# ten_y    0.379434  0.375285  0.418880  0.536619  0.776689  0.917525  1.000000

# %%
np.linalg.matrix_rank(forwards)
# Out:
# 7

# %%
### OK All have the correct rank! We are good with these

# %%
ylds.describe()
# Out:
#            three_m        six_m        one_y        two_y      three_y  \
# count  3313.000000  3313.000000  3313.000000  3313.000000  3313.000000
# mean      0.011427     0.012523     0.013427     0.015406     0.017595
# std       0.016504     0.016720     0.016194     0.014783     0.013717
# min       0.000000     0.000200     0.000800     0.001600     0.002800
# 25%       0.000600     0.001200     0.001900     0.004700     0.008300
# 50%       0.001800     0.003100     0.004900     0.008700     0.012700
# 75%       0.017800     0.019500     0.021200     0.023400     0.024500
# max       0.051900     0.053300     0.053000     0.052900     0.052600
#
#             five_y      seven_y        ten_y
# count  3313.000000  3313.000000  3313.000000
# mean      0.022151     0.025897     0.029388
# std       0.011938     0.010655     0.009759
# min       0.005600     0.009100     0.013700
# 25%       0.014000     0.018800     0.021900
# 50%       0.018400     0.022800     0.027100
# ...

# %%
zeros.describe()
# Out:
#            three_m        six_m        one_y        two_y      three_y  \
# count  3313.000000  3313.000000  3313.000000  3313.000000  3313.000000
# mean      0.011427     0.012523     0.013427     0.015489     0.017683
# std       0.016504     0.016720     0.016194     0.014752     0.013689
# min       0.000000     0.000200     0.000800     0.001700     0.002900
# 25%       0.000600     0.001200     0.001900     0.004800     0.008400
# 50%       0.001800     0.003100     0.004900     0.008800     0.012800
# 75%       0.017800     0.019500     0.021200     0.023500     0.024600
# max       0.051900     0.053300     0.053000     0.052900     0.052600
#
#             five_y      seven_y        ten_y
# count  3313.000000  3313.000000  3313.000000
# mean      0.022271     0.026188     0.029922
# std       0.011916     0.010632     0.009779
# min       0.005620     0.009190     0.013840
# 25%       0.014150     0.019050     0.022300
# 50%       0.018550     0.023120     0.027800
# ...

# %%
forwards.describe()
# Out:
#              six_m        one_y        two_y      three_y       five_y  \
# count  3313.000000  3313.000000  3313.000000  3313.000000  3313.000000
# mean      0.012523     0.013427     0.017678     0.022241     0.029422
# std       0.016720     0.016194     0.013664     0.012248     0.010659
# min       0.000200     0.000800     0.002502     0.004105     0.009730
# 25%       0.001200     0.001900     0.007921     0.013559     0.022186
# 50%       0.003100     0.004900     0.012949     0.019413     0.027740
# 75%       0.019500     0.021200     0.024954     0.028101     0.038071
# max       0.053300     0.053000     0.053497     0.053087     0.053215
#
#            seven_y        ten_y
# count  3313.000000  3313.000000
# mean      0.036375     0.039071
# std       0.009715     0.010204
# min       0.017387     0.018246
# 25%       0.028230     0.030026
# 50%       0.033950     0.037701
# 75%       0.045670     0.049184
# max       0.055391     0.061604

# %%
# testing my first difference calculation
diff_forwards = forwards.diff()
diff_forwards.head()
# Out:
#              six_m   one_y     two_y       three_y    five_y   seven_y  \
# Date
# 2006-01-03     NaN     NaN       NaN           NaN       NaN       NaN
# 2006-01-04 -0.0003 -0.0003 -0.000306 -1.049095e-07 -0.000204  0.000189
# 2006-01-05  0.0000  0.0001  0.000102  1.021125e-04  0.000102 -0.000256
# 2006-01-06  0.0002  0.0002  0.000613  1.022224e-04  0.000306 -0.000087
# 2006-01-09  0.0001  0.0001 -0.000102  0.000000e+00  0.000000  0.000358
#
#                ten_y
# Date
# 2006-01-03       NaN
# 2006-01-04 -0.000126
# 2006-01-05  0.000000
# 2006-01-06  0.000194
# 2006-01-09 -0.000273

# %%
forwards['d_six_m'] = diff_forwards['six_m']
forwards['d_one_y'] = diff_forwards['one_y']
forwards['d_two_y'] = diff_forwards['two_y']
forwards['d_three_y'] = diff_forwards['three_y']
forwards['d_five_y'] = diff_forwards['five_y']
forwards['d_seven_y'] = diff_forwards['seven_y']
forwards['d_ten_y'] = diff_forwards['ten_y']

# %%
forwards.head()
# Out:
#              six_m   one_y     two_y   three_y    five_y   seven_y     ten_y  \
# Date
# 2006-01-03  0.0440  0.0438  0.043462  0.042645  0.043437  0.044239  0.045619
# 2006-01-04  0.0437  0.0435  0.043156  0.042645  0.043232  0.044428  0.045493
# 2006-01-05  0.0437  0.0436  0.043258  0.042747  0.043335  0.044172  0.045493
# 2006-01-06  0.0439  0.0438  0.043871  0.042850  0.043641  0.044085  0.045688
# 2006-01-09  0.0440  0.0439  0.043769  0.042850  0.043641  0.044443  0.045415
#
#             d_six_m  d_one_y   d_two_y     d_three_y  d_five_y  d_seven_y  \
# Date
# 2006-01-03      NaN      NaN       NaN           NaN       NaN        NaN
# 2006-01-04  -0.0003  -0.0003 -0.000306 -1.049095e-07 -0.000204   0.000189
# 2006-01-05   0.0000   0.0001  0.000102  1.021125e-04  0.000102  -0.000256
# 2006-01-06   0.0002   0.0002  0.000613  1.022224e-04  0.000306  -0.000087
# 2006-01-09   0.0001   0.0001 -0.000102  0.000000e+00  0.000000   0.000358
#
#              d_ten_y
# Date
# ...

# %%
whos
# Out:
# Variable    Type         Data/Info
# ----------------------------------
# axs         ndarray      3x3: 9 elems, type `object`, 72 bytes
# col_names   Index        Index(['six_m', 'one_y', <...>'ten_y'], dtype='object')
# corr_ylds   DataFrame              three_m     six<...>50  \nten_y    1.000000
# fig         Figure       Figure(864x864)
# forwards    DataFrame                 six_m   one_<...>\n[3313 rows x 7 columns]
# my_rank     int64        8
# np          module       <module 'numpy' from '/an<...>kages/numpy/__init__.py'>
# pickle      module       <module 'pickle' from '/a<...>lib/python3.6/pickle.py'>
# plt         module       <module 'matplotlib.pyplo<...>es/matplotlib/pyplot.py'>
# test        Series       Date\n2006-01-03   -8.000<...>gth: 3313, dtype: float64
# ylds        DataFrame                three_m   six<...>\n[3313 rows x 8 columns]
# zeros       DataFrame                three_m   six<...>\n[3313 rows x 8 columns]

# %%
plt.plot(forwards['7 YR'])

# %%
test = ylds['10 YR'] - zeros['10 YR']

# %%
plt.hist(test)
# Out:
# (array([ 62., 181., 189., 308., 329., 312., 413., 596., 667., 256.]),
#  array([-1.510e-03, -1.351e-03, -1.192e-03, -1.033e-03, -8.740e-04,
#         -7.150e-04, -5.560e-04, -3.970e-04, -2.380e-04, -7.900e-05,
#          8.000e-05]),
#  <a list of 10 Patch objects>)

# %%
fig, axs = plt.subplots(3,3, figsize = (12,12))

axs[0,0].plot(forwards['5 YR'], color='k')
axs[0,0].grid()
axs[0,0].set_facecolor("whitesmoke")
axs[0,0].set_title("5 YR forward")
axs[0,1].plot(zeros['5 YR'], color='r')
axs[0,1].grid()
axs[0,1].set_facecolor("whitesmoke")
axs[0,1].set_title("5 YR Zero")
axs[0,2].plot(ylds['5 YR'], color='r')
axs[0,2].grid()
axs[0,2].set_facecolor("whitesmoke")
axs[0,2].set_title("5 YR yields")


axs[1,0].plot(forwards['7 YR'], color='k')
axs[1,0].grid()
axs[1,0].set_facecolor("whitesmoke")
axs[1,0].set_title("7 YR forward")
axs[1,1].plot(zeros['7 YR'], color='r')
axs[1,1].grid()
axs[1,1].set_facecolor("whitesmoke")
axs[1,1].set_title("7 YR Zero")
axs[1,2].plot(ylds['7 YR'], color='r')
axs[1,2].grid()
axs[1,2].set_facecolor("whitesmoke")
axs[1,2].set_title("7 YR yields")

axs[2,0].plot(forwards['10 YR'], color='k')
axs[2,0].grid()
axs[2,0].set_facecolor("whitesmoke")
axs[2,0].set_title("10 YR forward")
axs[2,1].plot(zeros['10 YR'], color='r')
axs[2,1].grid()
axs[2,1].set_facecolor("whitesmoke")
axs[2,1].set_title("10 YR Zero")
axs[2,2].plot(ylds['10 YR'], color='r')
axs[2,2].grid()
axs[2,2].set_facecolor("whitesmoke")
axs[2,2].set_title("10 YR yields")


plt.savefig('forward_rate_check.png')

# %%
ylds.tail()
# Out:
#               3 MO    6 MO    1 YR    2 YR    3 YR    5 YR    7 YR   10 YR
# Date
# 2019-03-22  0.0246  0.0248  0.0245  0.0231  0.0224  0.0224  0.0234  0.0244
# 2019-03-25  0.0246  0.0249  0.0241  0.0226  0.0219  0.0221  0.0232  0.0243
# 2019-03-26  0.0246  0.0249  0.0244  0.0224  0.0218  0.0218  0.0229  0.0241
# 2019-03-27  0.0244  0.0246  0.0240  0.0222  0.0216  0.0218  0.0228  0.0239
# 2019-03-28  0.0243  0.0244  0.0240  0.0223  0.0218  0.0220  0.0229  0.0239

# %%
ylds.head()
# Out:
#               3 MO    6 MO    1 YR    2 YR    3 YR    5 YR    7 YR   10 YR
# Date
# 2006-01-03  0.0416  0.0440  0.0438  0.0434  0.0430  0.0430  0.0432  0.0437
# 2006-01-04  0.0419  0.0437  0.0435  0.0431  0.0428  0.0428  0.0431  0.0436
# 2006-01-05  0.0420  0.0437  0.0436  0.0432  0.0429  0.0429  0.0431  0.0436
# 2006-01-06  0.0422  0.0439  0.0438  0.0436  0.0432  0.0432  0.0433  0.0438
# 2006-01-09  0.0423  0.0440  0.0439  0.0436  0.0432  0.0432  0.0434  0.0438

# %%
plt.plot(ylds['5 YR'])
plt.plot(ylds['7 YR'])

# %%
### Testing the baseline model
import pickle
dict_out = pickle.load(open("initial_fcst_error", "rb" ))

# %%
#dict_out = {'fcst_change': fcst_change,
#            'actual_change': actual_change,
#            'fcst_error': fcst_error}


forecast_change = dict_out['fcst_change']
actual_change = dict_out['actual_change']
fcst_error = dict_out['fcst_error']

# %%
fig, axs = plt.subplots(3,1, figsize = (15,15))
axs[0].plot(forecast_change[:,0])
axs[0].set_title('forecasted daily change in 6 month rate')

axs[1].plot(actual_change[:,0])
axs[1].set_title('actual change in 6 month rate')

axs[2].plot(fcst_error[:,0])
axs[2].set_title('forecasted error')
# Out:
# Text(0.5, 1.0, 'forecasted error')

# %%
fig, axs = plt.subplots(7, 2, figsize = (15,15))
fig.suptitle('Baseline HJM Model Noise', fontsize=24)
axs[0,0].plot(fcst_error[:,0])
axs[0,0].set_title('Base Model error 6 month forward rate')
#axs[0,1].sns.kdeplot(fcst_error[:,0], share = True, color = 'r')
sns.distplot(fcst_error[:,0], hist=False, color = 'red', kde_kws={'shade': True}, ax=axs[0,1])
axs[0,1].set_title('Distribution of Base Model for 6M forward rate')


axs[1,0].plot(fcst_error[:,1])
axs[1,0].set_title('Base Model error 1 year forward rate')
#axs[1,1].hist(fcst_error[:,0], bins = 20)
sns.distplot(fcst_error[:,1], hist=False, color = 'red', kde_kws={'shade': True}, ax=axs[1,1])
axs[1,1].set_title('Distribution of Base Model for 1Y forward rate')


axs[2,0].plot(fcst_error[:,2])
axs[2,0].set_title('Base Model error 2 year forward rate')
#axs[2,1].hist(fcst_error[:,0], bins = 20)
sns.distplot(fcst_error[:,2], hist=False, color = 'red', kde_kws={'shade': True}, ax=axs[2,1])
axs[2,1].set_title('Distribution of Base Model for 2Y Forward rate')


axs[3,0].plot(fcst_error[:,3])
axs[3,0].set_title('Base Model error 3 year forward rate')
#axs[3,1].hist(fcst_error[:,0], bins = 20)
sns.distplot(fcst_error[:,3], hist=False, color = 'red', kde_kws={'shade': True}, ax=axs[3,1])
axs[3,1].set_title('Distribution of Base Model for 3Y forward rate')


axs[4,0].plot(fcst_error[:,4])
axs[4,0].set_title('Base Model error 5 year forward rate')
#axs[4,1].hist(fcst_error[:,0], bins = 20)
sns.distplot(fcst_error[:,4], hist=False, color = 'red', kde_kws={'shade': True}, ax=axs[4,1])
axs[4,1].set_title('Distribution of Base Model for 5Y forward rate')


axs[5,0].plot(fcst_error[:,5])
axs[5,0].set_title('Base Model error 7 year forward rate')
#axs[5,1].hist(fcst_error[:,0], bins = 20)
sns.distplot(fcst_error[:,5], hist=False, color = 'red', kde_kws={'shade': True}, ax=axs[5,1])
axs[5,1].set_title('Distribution of Base Model for 7Y Forward rate')


axs[6,0].plot(fcst_error[:,6])
axs[6,0].set_title('Base Model error 10 year forward rate')

#axs[6,1].hist(fcst_error[:,0], bins = 20)
sns.distplot(fcst_error[:,6], hist=False, color = 'red', kde_kws={'shade': True}, ax=axs[6,1])
axs[6,1].set_title('Distribution of Base Model for 10Y forward rate')

axs[0,0].grid()
axs[0,1].grid()

axs[1,0].grid()
axs[1,1].grid()

axs[2,0].grid()
axs[2,1].grid()
axs[3,0].grid()
axs[3,1].grid()
axs[4,0].grid()
axs[4,1].grid()
axs[5,0].grid()
axs[5,1].grid()
axs[6,0].grid()
axs[6,1].grid()

axs[0,0].set_facecolor('whitesmoke')
axs[1,0].set_facecolor('whitesmoke')
axs[2,0].set_facecolor('whitesmoke')
axs[3,0].set_facecolor('whitesmoke')
axs[4,0].set_facecolor('whitesmoke')
axs[5,0].set_facecolor('whitesmoke')
axs[6,0].set_facecolor('whitesmoke')

axs[0,1].set_facecolor('whitesmoke')
axs[1,1].set_facecolor('whitesmoke')
axs[2,1].set_facecolor('whitesmoke')
axs[3,1].set_facecolor('whitesmoke')
axs[4,1].set_facecolor('whitesmoke')
axs[5,1].set_facecolor('whitesmoke')
axs[6,1].set_facecolor('whitesmoke')



fig.tight_layout()
fig.subplots_adjust(top = .92)
plt.savefig('baseline_model_error.png')

# %%
fig, axs = plt.subplots(7, 2, figsize = (15,15))
fig.suptitle('Changes in Forward Rates ', fontsize=24)
axs[0,0].plot(actual_change[:,0])
axs[0,0].set_title('Base Model error 6 month forward rate')
#axs[0,1].sns.kdeplot(fcst_error[:,0], share = True, color = 'r')
sns.distplot(actual_change[:,0], hist=False, color = 'red', kde_kws={'shade': True}, ax=axs[0,1])
axs[0,1].set_title('Distribution of Base Model for 6M forward rate')


axs[1,0].plot(actual_change[:,1])
axs[1,0].set_title('Base Model error 1 year forward rate')
#axs[1,1].hist(fcst_error[:,0], bins = 20)
sns.distplot(actual_change[:,1], hist=False, color = 'red', kde_kws={'shade': True}, ax=axs[1,1])
axs[1,1].set_title('Distribution of Base Model for 1Y forward rate')


axs[2,0].plot(actual_change[:,2])
axs[2,0].set_title('Base Model error 2 year forward rate')
#axs[2,1].hist(fcst_error[:,0], bins = 20)
sns.distplot(actual_change[:,2], hist=False, color = 'red', kde_kws={'shade': True}, ax=axs[2,1])
axs[2,1].set_title('Distribution of Base Model for 2Y Forward rate')


axs[3,0].plot(actual_change[:,3])
axs[3,0].set_title('Base Model error 3 year forward rate')
#axs[3,1].hist(fcst_error[:,0], bins = 20)
sns.distplot(actual_change[:,3], hist=False, color = 'red', kde_kws={'shade': True}, ax=axs[3,1])
axs[3,1].set_title('Distribution of Base Model for 3Y forward rate')


axs[4,0].plot(actual_change[:,4])
axs[4,0].set_title('Base Model error 5 year forward rate')
#axs[4,1].hist(fcst_error[:,0], bins = 20)
sns.distplot(actual_change[:,4], hist=False, color = 'red', kde_kws={'shade': True}, ax=axs[4,1])
axs[4,1].set_title('Distribution of Base Model for 5Y forward rate')


axs[5,0].plot(actual_change[:,5])
axs[5,0].set_title('Base Model error 7 year forward rate')
#axs[5,1].hist(fcst_error[:,0], bins = 20)
sns.distplot(actual_change[:,5], hist=False, color = 'red', kde_kws={'shade': True}, ax=axs[5,1])
axs[5,1].set_title('Distribution of Base Model for 7Y Forward rate')


axs[6,0].plot(actual_change[:,6])
axs[6,0].set_title('Base Model error 10 year forward rate')

#axs[6,1].hist(fcst_error[:,0], bins = 20)
sns.distplot(actual_change[:,6], hist=False, color = 'red', kde_kws={'shade': True}, ax=axs[6,1])
axs[6,1].set_title('Distribution of Base Model for 10Y forward rate')

axs[0,0].grid()
axs[0,1].grid()

axs[1,0].grid()
axs[1,1].grid()

axs[2,0].grid()
axs[2,1].grid()
axs[3,0].grid()
axs[3,1].grid()
axs[4,0].grid()
axs[4,1].grid()
axs[5,0].grid()
axs[5,1].grid()
axs[6,0].grid()
axs[6,1].grid()

axs[0,0].set_facecolor('whitesmoke')
axs[1,0].set_facecolor('whitesmoke')
axs[2,0].set_facecolor('whitesmoke')
axs[3,0].set_facecolor('whitesmoke')
axs[4,0].set_facecolor('whitesmoke')
axs[5,0].set_facecolor('whitesmoke')
axs[6,0].set_facecolor('whitesmoke')

axs[0,1].set_facecolor('whitesmoke')
axs[1,1].set_facecolor('whitesmoke')
axs[2,1].set_facecolor('whitesmoke')
axs[3,1].set_facecolor('whitesmoke')
axs[4,1].set_facecolor('whitesmoke')
axs[5,1].set_facecolor('whitesmoke')
axs[6,1].set_facecolor('whitesmoke')



fig.tight_layout()
fig.subplots_adjust(top = .92)
plt.savefig('forward_changes_over_time.png')

# %%
print('Baseline model forecasted change in 6 month rates: ', np.mean(forecast_change[:,0]))
print('Average change in actual 6 month rates: ', np.mean(actual_change[:,0]))
print('Average forecast error in 6 month rates', np.mean(fcst_error[:,0]))
# Out:
# Baseline model forecasted change in 6 month rates:  6.129922981060356e-06
# Average change in actual 6 month rates:  1.629778672032193e-05
# Average forecast error in 6 month rates -1.0167863739261576e-05

# %%
plt.hist(fcst_error[:,0], bins=20, normed=True)
# Out:
# /anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6521: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   alternative="'density'", removal="3.1")
# (array([  22.3418749 ,    0.        ,   22.3418749 ,    0.        ,
#           22.3418749 ,   67.02562469,  290.44437365,  714.93999669,
#         1117.09374482, 1988.42686578,  268.10249876, 2837.41811185,
#         2234.18748965,  692.59812179,  424.49562303,  178.73499917,
#          134.05124938,   67.02562469,    0.        ,   22.3418749 ]),
#  array([-9.92649029e-04, -9.02590677e-04, -8.12532325e-04, -7.22473973e-04,
#         -6.32415621e-04, -5.42357269e-04, -4.52298917e-04, -3.62240565e-04,
#         -2.72182213e-04, -1.82123861e-04, -9.20655088e-05, -2.00715678e-06,
#          8.80511953e-05,  1.78109547e-04,  2.68167899e-04,  3.58226251e-04,
#          4.48284603e-04,  5.38342955e-04,  6.28401307e-04,  7.18459660e-04,
# ...

# %%
fig, axs = plt.subplots(3,1, figsize = (15,15))
axs[0].plot(forecast_change[:,6])
axs[0].set_title('forecasted daily change in 10 yr forward rate')

axs[1].plot(actual_change[:,6])
axs[1].set_title('actual change in 10 yr forward rate')

axs[2].plot(fcst_error[:,6])
axs[2].set_title('forecasted error')
# Out:
# Text(0.5, 1.0, 'forecasted error')

# %%
plt.plot(forecast_change[:,6], label='forecast change' )
plt.plot(actual_change[:,6], label='actual change')
plt.legend()

plt.title('HJM Model Forecasted Change in 10 YR Forward Rates vs. Actual')
# Out:
# Text(0.5, 1.0, 'HJM Model Forecasted Change in 10 YR Forward Rates vs. Actual')

# %%
print('Baseline model forecasted change in 6 month rates: ', np.mean(forecast_change[:,6]))
print('Average change in actual 6 month rates: ', np.mean(actual_change[:,6]))
print('Average forecast error in 6 month rates', np.mean(fcst_error[:,6]))
# Out:
# Baseline model forecasted change in 6 month rates:  5.495816310814097e-07
# Average change in actual 6 month rates:  8.00451088082242e-06
# Average forecast error in 6 month rates -7.45492924974101e-06

# %%
plt.hist(fcst_error[:,6], bins=20, normed=True)
# Out:
# (array([ 19.94229833,   9.97114916,  29.91344749,  19.94229833,
#         129.62493913,  89.74034247, 329.0479224 , 329.0479224 ,
#         618.21124814, 688.00929228, 697.98044145, 727.89388894,
#         538.44205483, 329.0479224 , 209.39413243,  69.79804414,
#          49.85574582,  39.88459665,   9.97114916,  19.94229833]),
#  array([-2.07302253e-03, -1.87123311e-03, -1.66944368e-03, -1.46765426e-03,
#         -1.26586484e-03, -1.06407542e-03, -8.62285993e-04, -6.60496570e-04,
#         -4.58707148e-04, -2.56917725e-04, -5.51283019e-05,  1.46661121e-04,
#          3.48450544e-04,  5.50239967e-04,  7.52029389e-04,  9.53818812e-04,
#          1.15560824e-03,  1.35739766e-03,  1.55918708e-03,  1.76097650e-03,
#          1.96276593e-03]),
#  <a list of 20 Patch objects>)

# %%
whos
# Out:
# Variable          Type         Data/Info
# ----------------------------------------
# actual_change     ndarray      497x7: 3479 elems, type `float64`, 27832 bytes
# actuals           ndarray      497x7: 3479 elems, type `float64`, 27832 bytes
# axs               ndarray      3: 3 elems, type `object`, 24 bytes
# col_names         Index        Index(['six_m', 'one_y', <...>'ten_y'], dtype='object')
# corr_ylds         DataFrame              three_m     six<...>50  \nten_y    1.000000
# dict_out          dict         n=3
# diff_forwards     DataFrame                 six_m   one_<...>\n[3313 rows x 7 columns]
# fcst_error        ndarray      497x7: 3479 elems, type `float64`, 27832 bytes
# fcst_errors       ndarray      497x7: 3479 elems, type `float64`, 27832 bytes
# fig               Figure       Figure(1080x1080)
# forecast          ndarray      497x7: 3479 elems, type `float64`, 27832 bytes
# forecast_change   ndarray      497x7: 3479 elems, type `float64`, 27832 bytes
# ...

# %%
ylds.sample()
# Out:
#             three_m  six_m   one_y   two_y  three_y  five_y  seven_y   ten_y
# Date
# 2018-01-04   0.0141  0.016  0.0182  0.0196   0.0205  0.0227   0.0238  0.0246

# %%
ylds.head()
# Out:
#             three_m   six_m   one_y   two_y  three_y  five_y  seven_y   ten_y
# Date
# 2006-01-03   0.0416  0.0440  0.0438  0.0434   0.0430  0.0430   0.0432  0.0437
# 2006-01-04   0.0419  0.0437  0.0435  0.0431   0.0428  0.0428   0.0431  0.0436
# 2006-01-05   0.0420  0.0437  0.0436  0.0432   0.0429  0.0429   0.0431  0.0436
# 2006-01-06   0.0422  0.0439  0.0438  0.0436   0.0432  0.0432   0.0433  0.0438
# 2006-01-09   0.0423  0.0440  0.0439  0.0436   0.0432  0.0432   0.0434  0.0438

# %%
ylds.iloc[700:850]
# Out:
#             three_m   six_m   one_y   two_y  three_y  five_y  seven_y   ten_y
# Date
# 2008-10-16   0.0046  0.0118  0.0129  0.0161   0.0190  0.0284   0.0333  0.0399
# 2008-10-17   0.0083  0.0125  0.0134  0.0164   0.0190  0.0283   0.0330  0.0398
# 2008-10-20   0.0124  0.0174  0.0169  0.0171   0.0200  0.0282   0.0326  0.0391
# 2008-10-21   0.0110  0.0161  0.0174  0.0158   0.0186  0.0263   0.0308  0.0376
# 2008-10-22   0.0105  0.0153  0.0164  0.0153   0.0179  0.0256   0.0300  0.0365
# 2008-10-23   0.0098  0.0151  0.0161  0.0154   0.0176  0.0257   0.0300  0.0363
# 2008-10-24   0.0089  0.0143  0.0160  0.0157   0.0180  0.0264   0.0309  0.0376
# 2008-10-27   0.0084  0.0136  0.0157  0.0159   0.0183  0.0267   0.0312  0.0379
# 2008-10-28   0.0077  0.0125  0.0153  0.0165   0.0185  0.0275   0.0321  0.0389
# 2008-10-29   0.0062  0.0110  0.0141  0.0158   0.0179  0.0277   0.0324  0.0393
# 2008-10-30   0.0041  0.0100  0.0136  0.0159   0.0182  0.0284   0.0330  0.0400
# ...

# %%
plt.plot(ylds)

# %%
actual_change.describe()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-61-54875af0d03b> in <module>
# ----> 1 actual_change.describe()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'describe'

# %%
whos
# Out:
# Variable          Type       Data/Info
# --------------------------------------
# actual_change     ndarray    497x7: 3479 elems, type `float64`, 27832 bytes
# axs               ndarray    7x2: 14 elems, type `object`, 112 bytes
# dict_out          dict       n=3
# fcst_error        ndarray    497x7: 3479 elems, type `float64`, 27832 bytes
# fig               Figure     Figure(1080x1080)
# forecast_change   ndarray    497x7: 3479 elems, type `float64`, 27832 bytes
# np                module     <module 'numpy' from '/an<...>kages/numpy/__init__.py'>
# pickle            module     <module 'pickle' from '/a<...>lib/python3.6/pickle.py'>
# plt               module     <module 'matplotlib.pyplo<...>es/matplotlib/pyplot.py'>
# sns               module     <module 'seaborn' from '/<...>ges/seaborn/__init__.py'>
