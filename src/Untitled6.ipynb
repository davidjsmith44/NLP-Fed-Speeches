# %%
import string
import numpy as np
import pandas as pd

from nltk.corpus import stopwords
from nltk.tokenize import RegexpTokenizer
from nltk.stem.porter import PorterStemmer

from nltk.tokenize import word_tokenize
from nltk.stem.porter import PorterStemmer
from nltk.stem.snowball import SnowballStemmer
from nltk.stem.wordnet import WordNetLemmatizer

from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.metrics.pairwise import linear_kernel, euclidean_distances


import os

# Importing all of the Fed Speeches
import pickle

# %%
df = pickle.load(open("mvp_fed_press_rel", 'rb'))
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42 entries, 0 to 41
# Data columns (total 2 columns):
# date    42 non-null datetime64[ns]
# text    42 non-null object
# dtypes: datetime64[ns](1), object(1)
# memory usage: 752.0+ bytes

# %%
df['text'][40]
# Out:
# "\n       Information received since the Federal Open Market Committee met in September suggests that economic activity is expanding at a moderate pace. Labor market conditions improved somewhat further, with solid job gains and a lower unemployment rate. On balance, a range of labor market indicators suggests that underutilization of labor resources is gradually diminishing. Household spending is rising moderately and business fixed investment is advancing, while the recovery in the housing sector remains slow. Inflation has continued to run below the Committee's longer-run objective. Market-based measures of inflation compensation have declined somewhat; survey-based measures of longer-term inflation expectations have remained stable.\n    \n       Consistent with its statutory mandate, the Committee seeks to foster maximum employment and price stability. The Committee expects that, with appropriate policy accommodation, economic activity will expand at a moderate pace, with labor market indicators and inflation moving toward levels the Committee judges consistent with its dual mandate. The Committee sees the risks to the outlook for economic activity and the labor market as nearly balanced. Although inflation in the near term will likely be held down by lower energy prices and other factors, the Committee judges that the likelihood of inflation running persistently below 2 percent has diminished somewhat since early this year.\n    \n       The Committee judges that there has been a substantial improvement in the outlook for the labor market since the inception of its current asset purchase program. Moreover, the Committee continues to see sufficient underlying strength in the broader economy to support ongoing progress toward maximum employment in a context of price stability. Accordingly, the Committee decided to conclude its asset purchase program this month. The Committee is maintaining its existing policy of reinvesting principal payments from its holdings of agency debt and agency mortgage-backed securities in agency mortgage-backed securities and of rolling over maturing Treasury securities at auction. This policy, by keeping the Committee's holdings of longer-term securities at sizable levels, should help maintain accommodative financial conditions.\n    \n       To support continued progress toward maximum employment and price stability, the Committee today reaffirmed its view that the current 0 to 1/4 percent target range for the federal funds rate remains appropriate. In determining how long to maintain this target range, the Committee will assess progress--both realized and expected--toward its objectives of maximum employment and 2 percent inflation. This assessment will take into account a wide range of information, including measures of labor market conditions, indicators of inflation pressures and inflation expectations, and readings on financial developments. The Committee anticipates, based on its current assessment, that it likely will be appropriate to maintain the 0 to 1/4 percent target range for the federal funds rate for a considerable time following the end of its asset purchase program this month, especially if projected inflation continues to run below the Committee's 2 percent longer-run goal, and provided that longer-term inflation expectations remain well anchored. However, if incoming information indicates faster progress toward the Committee's employment and inflation objectives than the Committee now expects, then increases in the target range for the federal funds rate are likely to occur sooner than currently anticipated. Conversely, if progress proves slower than expected, then increases in the target range are likely to occur later than currently anticipated.\n    \n       When the Committee decides to begin to remove policy accommodation, it will take a balanced approach consistent with its longer-run goals of maximum employment and inflation of 2 percent. The Committee currently antici ...

# %%
df.sort_values(by=['date'], ascending = False, inplace = True)
df.reset_index(drop=True, inplace=True)

# %%
df.head()
# Out:
#         date                                               text
# 0 2019-03-20  Information received since the Federal Open Ma...
# 1 2019-01-30  Information received since the Federal Open Ma...
# 2 2018-12-19  Information received since the Federal Open Ma...
# 3 2018-11-08  Information received since the Federal Open Ma...
# 4 2018-09-26  Information received since the Federal Open Ma...

# %%
df.tail()
# Out:
#          date                                               text
# 37 2014-07-30  \n       Information received since the Federa...
# 38 2014-06-18  \n       Information received since the Federa...
# 39 2014-04-30  \n       Information received since the Federa...
# 40 2014-03-19  \n       Information received since the Federa...
# 41 2014-01-29  \n       Information received since the Federa...

# %%
i = 5
this_date = df['date'][i]
n_speeches = 5

# %%
this_date
# Out:
# Timestamp('2018-08-01 00:00:00')

# %%
def create_speech_dfs(df, date, numb_speeches):
    '''
    For a given date, the most recent speeches numb_speeches and the next date speeches
    are returned as dataframes

    INPUTS:
        df - the dataframe of all fed speeches
        date - the date needed to include no speeches before
        num_speeches - the number of most recent speeches to include

    OUTPUTS:
        hist_df - this is a subset of the original dataframe with same columns
        new_df - a subset of the original dataframe for the new speeches
    '''
    hist_df = df[df['date']< date]
    if len(hist_df)> numb_speeches:
            hist_df = hist_df.iloc[0:numb_speeches]

    new_df = df[df['date']==date]

    return hist_df, new_df

# %%
h_df, n_df = create_speech_dfs(df, this_date, n_speeches)

# %%
n_df
# Out:
#         date                                               text
# 5 2018-08-01  Information received since the Federal Open Ma...

# %%
doc_list = list(h_df['text'])

# %%
doc_list
# Out:
# ["Information received since the Federal Open Market Committee met in May indicates that the labor market has continued to strengthen and that economic activity has been rising at a solid rate. Job gains have been strong, on average, in recent months, and the unemployment rate has declined. Recent data suggest that growth of household spending has picked up, while business fixed investment has continued to grow strongly. On a 12-month basis, both overall inflation and inflation for items other than food and energy have moved close to 2 percent. Indicators of longer-term inflation expectations are little changed, on balance.Consistent with its statutory mandate, the Committee seeks to foster maximum employment and price stability. The Committee expects that further gradual increases in the target range for the federal funds rate will be consistent with sustained expansion of economic activity, strong labor market conditions, and inflation near the Committee's symmetric 2 percent objective over the medium term. Risks to the economic outlook appear roughly balanced.In view of realized and expected labor market conditions and inflation, the Committee decided to raise the target range for the federal funds rate to 1-3/4 to 2 percent. The stance of monetary policy remains accommodative, thereby supporting strong labor market conditions and a sustained return to 2 percent inflation.In determining the timing and size of future adjustments to the target range for the federal funds rate, the Committee will assess realized and expected economic conditions relative to its maximum employment objective and its symmetric 2 percent inflation objective. This assessment will take into account a wide range of information, including measures of labor market conditions, indicators of inflation pressures and inflation expectations, and readings on financial and international developments.Voting for the FOMC monetary policy action were Jerome H. Powell, Chairman; William C. Dudley, Vice Chairman; Thomas I. Barkin; Raphael W. Bostic; Lael Brainard; Loretta J. Mester; Randal K. Quarles; and John C. Williams.Implementation Note issued June 13, 2018",
#  "Information received since the Federal Open Market Committee met in March indicates that the labor market has continued to strengthen and that economic activity has been rising at a moderate rate. Job gains have been strong, on average, in recent months, and the unemployment rate has stayed low. Recent data suggest that growth of household spending moderated from its strong fourth-quarter pace, while business fixed investment continued to grow strongly. On a 12-month basis, both overall inflation and inflation for items other than food and energy have moved close to 2 percent. Market-based measures of inflation compensation remain low; survey-based measures of longer-term inflation expectations are little changed, on balance.Consistent with its statutory mandate, the Committee seeks to foster maximum employment and price stability. The Committee expects that, with further gradual adjustments in the stance of monetary policy, economic activity will expand at a moderate pace in the medium term and labor market conditions will remain strong. Inflation on a 12-month basis is expected to run near the Committee's symmetric 2 percent objective over the medium term. Risks to the economic outlook appear roughly balanced.In view of realized and expected labor market conditions and inflation, the Committee decided to maintain the target range for the federal funds rate at 1-1/2 to 1-3/4 percent. The stance of monetary policy remains accommodative, thereby supporting strong labor market conditions and a sustained return to 2 percent inflation.In determining the timing and size of future adjustments to the target range for the federal funds rate, the Committee will assess realized and expected economic conditions relative to its objectives of maximum employment and 2 percent inflation. This assessment will take into account a wide range of information, including measures of labor market conditions, indicators of inflation pressures and inflation expectations, and readings on financial and international developments. The Committee will carefully monitor actual and expected inflation developments relative to its symmetric inflation goal. The Committee expects that economic conditions will evolve in a manner that will warrant further gradual increases in the federal funds rate; the federal funds rate is likely to remain, for some time, below levels that are expected to prevail in the longer run. However, the actual path of the federal funds rate will depend on the economic outlook as informed by incoming data.Voting for the FOMC monetary policy action were Jerome H. Powell, Chairman; William C. Dudley, Vice Chairman; Thomas I. Barkin; Raphael W. Bostic; Lael Brainard; Loretta J. Mester; Randal K. Quarles; and John C. Williams.Implementation Note issued May 2, 2018",
#  "Information received since the Federal Open Market Committee met in January indicates that the labor market has continued to strengthen and that economic activity has been rising at a moderate rate. Job gains have been strong in recent months, and the unemployment rate has stayed low. Recent data suggest that growth rates of household spending and business fixed investment have moderated from their strong fourth-quarter readings. On a 12-month basis, both overall inflation and inflation for items other than food and energy have continued to run below 2 percent. Market-based measures of inflation compensation have increased in recent months but remain low; survey-based measures of longer-term inflation expectations are little changed, on balance.Consistent with its statutory mandate, the Committee seeks to foster maximum employment and price stability. The economic outlook has strengthened in recent months. The Committee expects that, with further gradual adjustments in the stance of monetary policy, economic activity will expand at a moderate pace in the medium term and labor market conditions will remain strong. Inflation on a 12-month basis is expected to move up in coming months and to stabilize around the Committee's 2 percent objective over the medium term. Near-term risks to the economic outlook appear roughly balanced, but the Committee is monitoring inflation developments closely.In view of realized and expected labor market conditions and inflation, the Committee decided to raise the target range for the federal funds rate to 1-1/2 to 1-3/4 percent. The stance of monetary policy remains accommodative, thereby supporting strong labor market conditions and a sustained return to 2 percent inflation.In determining the timing and size of future adjustments to the target range for the federal funds rate, the Committee will assess realized and expected economic conditions relative to its objectives of maximum employment and 2 percent inflation. This assessment will take into account a wide range of information, including measures of labor market conditions, indicators of inflation pressures and inflation expectations, and readings on financial and international developments. The Committee will carefully monitor actual and expected inflation developments relative to its symmetric inflation goal. The Committee expects that economic conditions will evolve in a manner that will warrant further gradual increases in the federal funds rate; the federal funds rate is likely to remain, for some time, below levels that are expected to prevail in the longer run. However, the actual path of the federal funds rate will depend on the economic outlook as informed by incoming data.Voting for the FOMC monetary policy action were Jerome H. Powell, Chairman; William C. Dudley, Vice Chairman; Thomas I. Barkin; Raphael W. Bostic; Lael Brainard; Loretta J. Mester; Randal K. Quarles; and John C. Williams.Implementation Note issued March 21, 2018",
#  "Information received since the Federal Open Market Committee met in December indicates that the labor market has continued to strengthen and that economic activity has been rising at a solid rate. Gains in employment, household spending, and business fixed investment have been solid, and the unemployment rate has stayed low. On a 12-month basis, both overall inflation and inflation for items other than food and energy have continued to run below 2 percent. Market-based measures of inflation compensation have increased in recent months but remain low; survey-based measures of longer-term inflation expectations are little changed, on balance.Consistent with its statutory mandate, the Committee seeks to foster maximum employment and price stability. The Committee expects that, with further gradual adjustments in the stance of monetary policy, economic activity will expand at a moderate pace and labor market conditions will remain strong. Inflation on a 12â\x80\x91month basis is expected to move up this year and to stabilize around the Committee's 2 percent objective over the medium term. Near-term risks to the economic outlook appear roughly balanced, but the Committee is monitoring inflation developments closely.In view of realized and expected labor market conditions and inflation, the Committee decided to maintain the target range for the federal funds rate at 1-1/4 to 1â\x80\x911/2 percent. The stance of monetary policy remains accommodative, thereby supporting strong labor market conditions and a sustained return to 2 percent inflation.In determining the timing and size of future adjustments to the target range for the federal funds rate, the Committee will assess realized and expected economic conditions relative to its objectives of maximum employment and 2 percent inflation. This assessment will take into account a wide range of information, including measures of labor market conditions, indicators of inflation pressures and inflation expectations, and readings on financial and international developments. The Committee will carefully monitor actual and expected inflation developments relative to its symmetric inflation goal. The Committee expects that economic conditions will evolve in a manner that will warrant further gradual increases in the federal funds rate; the federal funds rate is likely to remain, for some time, below levels that are expected to prevail in the longer run. However, the actual path of the federal funds rate will depend on the economic outlook as informed by incoming data.Voting for the FOMC monetary policy action were Janet L. Yellen, Chair; William C. Dudley, Vice Chairman; Thomas I. Barkin; Raphael W. Bostic; Lael Brainard; Loretta J. Mester; Jerome H. Powell; Randal K. Quarles; and John C. Williams.Implementation Note issued January 31, 2018",
#  "Information received since the Federal Open Market Committee met in November indicates that the labor market has continued to strengthen and that economic activity has been rising at a solid rate. Averaging through hurricane-related fluctuations, job gains have been solid, and the unemployment rate declined further. Household spending has been expanding at a moderate rate, and growth in business fixed investment has picked up in recent quarters. On a 12-month basis, both overall inflation and inflation for items other than food and energy have declined this year and are running below 2 percent. Market-based measures of inflation compensation remain low; survey-based measures of longer-term inflation expectations are little changed, on balance.Consistent with its statutory mandate, the Committee seeks to foster maximum employment and price stability. Hurricane-related disruptions and rebuilding have affected economic activity, employment, and inflation in recent months but have not materially altered the outlook for the national economy. Consequently, the Committee continues to expect that, with gradual adjustments in the stance of monetary policy, economic activity will expand at a moderate pace and labor market conditions will remain strong. Inflation on a 12â\x80\x91month basis is expected to remain somewhat below 2 percent in the near term but to stabilize around the Committee's 2 percent objective over the medium term. Near-term risks to the economic outlook appear roughly balanced, but the Committee is monitoring inflation developments closely.In view of realized and expected labor market conditions and inflation, the Committee decided to raise the target range for the federal funds rate to 1-1/4 to 1â\x80\x911/2 percent. The stance of monetary policy remains accommodative, thereby supporting strong labor market conditions and a sustained return to 2 percent inflation.In determining the timing and size of future adjustments to the target range for the federal funds rate, the Committee will assess realized and expected economic conditions relative to its objectives of maximum employment and 2 percent inflation. This assessment will take into account a wide range of information, including measures of labor market conditions, indicators of inflation pressures and inflation expectations, and readings on financial and international developments. The Committee will carefully monitor actual and expected inflation developments relative to its symmetric inflation goal. The Committee expects that economic conditions will evolve in a manner that will warrant gradual increases in the federal funds rate; the federal funds rate is likely to remain, for some time, below levels that are expected to prevail in the longer run. However, the actual path of the federal funds rate will depend on the economic outlook as informed by incoming data.Voting for the FOMC monetary policy action were Janet L. Yellen, Chair; William C. Dudley, Vice Chairman; Lael Brainard; Patrick Harker; Robert S. Kaplan; Jerome H. Powell; and Randal K. Quarles. Voting against the action were Charles L. Evans and Neel Kashkari, who preferred at this meeting to maintain the existing target range for the federal funds rate.Implementation Note issued December 13, 2017"]

# %%
tfidvect =TfidfVectorizer(lowercase=True,
                          stop_words='english',
                          max_features = 2000,
                          norm = 'l2',
                          use_idf = True,
                          smooth_idf=True,
                          sublinear_tf = False,
                          ngram_range = (1,3))

# %%
tfidf_vectorized = tfidvect.fit_transform(doc_list).toarray()

# %%
tfidvect.fit_transform(doc_list)
# Out:
# <5x1062 sparse matrix of type '<class 'numpy.float64'>'
# 	with 3211 stored elements in Compressed Sparse Row format>

# %%
new_text = n_df['text']
new_tokens = tfidf_vectorized.transform(new_text)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-38-ceced284f560> in <module>
#       1 new_text = n_df['text']
# ----> 2 new_tokens = tfidf_vectorized.transform(new_text)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'transform'

# %%
def transform_new_speech(new_df, model):
    '''
    takes the model fit on historical speeches and fits the new text to this model
    returns new_tokens which can go into the similarity calculation
    '''
    new_text = new_df['text']
    new_tokens = model.transform(new_text)
    return new_tokens

# %%
new_tokens = transform_new_speech(n_df, tfidvect)

# %%
new_tokens
# Out:
# <1x1062 sparse matrix of type '<class 'numpy.float64'>'
# 	with 442 stored elements in Compressed Sparse Row format>

# %%
tfidvect.vocabulary_
# Out:
# {'information': 470,
#  'received': 851,
#  'federal': 326,
#  'open': 703,
#  'market': 581,
#  'committee': 135,
#  'met': 621,
#  'indicates': 428,
#  'labor': 532,
#  'continued': 190,
#  'strengthen': 961,
#  'economic': 243,
#  'activity': 31,
#  'rising': 891,
#  'solid': 922,
#  'rate': 806,
#  'job': 516,
#  'gains': 371,
#  'strong': 967,
#  'average': 66,
#  'recent': 854,
#  'months': 657,
#  'unemployment': 1026,
#  'declined': 215,
#  'data': 200,
#  'suggest': 982,
#  'growth': 391,
#  'household': 401,
#  'spending': 932,
#  'picked': 746,
#  'business': 103,
#  'fixed': 334,
#  'investment': 482,
#  'grow': 388,
#  'strongly': 979,
#  '12': 0,
#  'month': 653,
#  'basis': 87,
#  'overall': 715,
#  'inflation': 436,
#  'items': 501,
#  'food': 346,
#  'energy': 270,
#  'moved': 668,
#  'close': 125,
#  'percent': 731,
#  'indicators': 431,
#  'longer': 549,
#  'term': 1006,
#  'expectations': 298,
#  'little': 546,
#  'changed': 119,
#  'balance': 72,
#  'consistent': 185,
#  'statutory': 954,
#  'mandate': 570,
#  'seeks': 916,
#  'foster': 351,
#  'maximum': 596,
#  'employment': 259,
#  'price': 773,
#  'stability': 941,
#  'expects': 320,
#  'gradual': 382,
#  'increases': 423,
#  'target': 1003,
#  'range': 798,
#  'funds': 358,
#  'sustained': 992,
#  'expansion': 292,
#  'conditions': 167,
#  'near': 674,
#  'symmetric': 997,
#  'objective': 693,
#  'medium': 608,
#  'risks': 896,
#  'outlook': 706,
#  'appear': 57,
#  'roughly': 902,
#  'balanced': 75,
#  'view': 1034,
#  'realized': 844,
#  'expected': 303,
#  'decided': 210,
#  'raise': 791,
#  'stance': 951,
#  'monetary': 642,
#  'policy': 751,
#  'remains': 885,
#  'accommodative': 18,
#  'supporting': 986,
#  'return': 888,
#  'determining': 225,
#  'timing': 1023,
#  'size': 919,
#  'future': 368,
#  'adjustments': 46,
#  'assess': 60,
#  'relative': 869,
#  'assessment': 63,
#  'account': 21,
#  'wide': 1045,
#  'including': 414,
#  'measures': 601,
#  'pressures': 767,
#  'readings': 839,
#  'financial': 331,
#  'international': 478,
#  'developments': 228,
#  'voting': 1037,
#  'fomc': 343,
#  'action': 24,
#  'jerome': 512,
#  'powell': 759,
#  'chairman': 112,
#  'william': 1048,
#  'dudley': 240,
#  'vice': 1030,
#  'thomas': 1017,
#  'barkin': 80,
#  'raphael': 803,
#  'bostic': 95,
#  'lael': 536,
#  'brainard': 98,
#  'loretta': 554,
#  'mester': 616,
#  'randal': 794,
#  'quarles': 778,
#  'john': 520,
#  'williams': 1051,
#  'implementation': 411,
#  'note': 683,
#  'issued': 491,
#  'june': 523,
#  '13': 6,
#  '2018': 13,
#  'information received': 473,
#  'received federal': 852,
#  'federal open': 329,
#  'open market': 704,
#  'market committee': 584,
#  'committee met': 148,
#  'met indicates': 624,
#  'indicates labor': 429,
#  'labor market': 533,
#  'market continued': 591,
#  'continued strengthen': 195,
#  'strengthen economic': 962,
#  'economic activity': 244,
#  'activity rising': 36,
#  'rising solid': 894,
#  'solid rate': 923,
#  'rate job': 828,
#  'job gains': 517,
#  'gains strong': 376,
#  'strong average': 968,
#  'average recent': 67,
#  'recent months': 857,
#  'months unemployment': 666,
#  'unemployment rate': 1027,
#  'rate declined': 815,
#  'declined recent': 218,
#  'recent data': 855,
#  'data suggest': 201,
#  'suggest growth': 983,
#  'growth household': 394,
#  'household spending': 402,
#  'spending picked': 939,
#  'picked business': 747,
#  'business fixed': 104,
#  'fixed investment': 335,
#  'investment continued': 483,
#  'continued grow': 191,
#  'grow strongly': 389,
#  'strongly 12': 980,
#  '12 month': 1,
#  'month basis': 654,
#  'basis overall': 93,
#  'overall inflation': 716,
#  'inflation inflation': 458,
#  'inflation items': 460,
#  'items food': 502,
#  'food energy': 347,
#  'energy moved': 275,
#  'moved close': 669,
#  'close percent': 126,
#  'percent indicators': 732,
#  'indicators longer': 434,
#  'longer term': 552,
#  'term inflation': 1007,
#  'inflation expectations': 453,
#  'expectations little': 299,
#  'little changed': 547,
#  'changed balance': 120,
#  'balance consistent': 73,
#  'consistent statutory': 186,
#  'statutory mandate': 955,
#  'mandate committee': 571,
#  'committee seeks': 158,
#  'seeks foster': 917,
#  'foster maximum': 352,
#  'maximum employment': 597,
#  'employment price': 268,
#  'price stability': 774,
#  'stability committee': 942,
#  'committee expects': 145,
#  'expects gradual': 323,
#  'gradual increases': 385,
#  'increases target': 426,
#  'target range': 1004,
#  'range federal': 799,
#  'federal funds': 327,
#  'funds rate': 359,
#  'rate consistent': 813,
#  'consistent sustained': 188,
#  'sustained expansion': 993,
#  'expansion economic': 293,
#  'activity strong': 39,
#  'strong labor': 975,
#  'market conditions': 586,
#  'conditions inflation': 172,
#  'inflation near': 462,
#  'near committee': 675,
#  'committee symmetric': 160,
#  'symmetric percent': 1000,
#  'percent objective': 742,
#  'objective medium': 696,
#  'medium term': 609,
#  'term risks': 1013,
#  'risks economic': 897,
#  'economic outlook': 252,
#  'outlook appear': 707,
#  'appear roughly': 58,
#  'roughly balanced': 903,
#  'balanced view': 78,
#  'view realized': 1035,
#  'realized expected': 845,
#  'expected labor': 310,
#  'inflation committee': 443,
#  'committee decided': 142,
#  'decided raise': 213,
#  'raise target': 792,
#  'rate percent': 832,
#  'percent stance': 744,
#  'stance monetary': 952,
#  'monetary policy': 643,
#  'policy remains': 757,
#  'remains accommodative': 886,
#  'accommodative supporting': 19,
#  'supporting strong': 987,
#  'conditions sustained': 180,
#  'sustained return': 995,
#  'return percent': 889,
#  'percent inflation': 734,
#  'inflation determining': 448,
#  'determining timing': 226,
#  'timing size': 1024,
#  'size future': 920,
#  'future adjustments': 369,
#  'adjustments target': 49,
#  'rate committee': 811,
#  'committee assess': 136,
#  'assess realized': 61,
#  'expected economic': 306,
#  'economic conditions': 249,
#  'conditions relative': 175,
#  'relative maximum': 870,
#  'employment objective': 264,
#  'objective symmetric': 698,
#  'inflation objective': 464,
#  'objective assessment': 694,
#  'assessment account': 64,
#  'account wide': 22,
#  'wide range': 1046,
#  'range information': 801,
#  'information including': 471,
#  'including measures': 415,
#  'measures labor': 604,
#  'conditions indicators': 170,
#  'indicators inflation': 432,
#  'inflation pressures': 466,
#  'pressures inflation': 768,
#  'expectations readings': 301,
#  'readings financial': 842,
#  'financial international': 332,
#  'international developments': 479,
#  'developments voting': 235,
#  'voting fomc': 1040,
#  'fomc monetary': 344,
#  'policy action': 752,
#  'action jerome': 29,
#  'jerome powell': 513,
#  'powell chairman': 760,
#  'chairman william': 117,
#  'william dudley': 1049,
#  'dudley vice': 241,
#  'vice chairman': 1031,
#  'chairman thomas': 115,
#  'thomas barkin': 1018,
#  'barkin raphael': 81,
#  'raphael bostic': 804,
#  'bostic lael': 96,
#  'lael brainard': 537,
#  'brainard loretta': 99,
#  'loretta mester': 555,
#  'mester randal': 619,
#  'randal quarles': 795,
#  'quarles john': 779,
#  'john williams': 521,
#  'williams implementation': 1052,
#  'implementation note': 412,
#  'note issued': 684,
#  'issued june': 497,
#  'june 13': 524,
#  '13 2018': 8,
#  'information received federal': 474,
#  'received federal open': 853,
#  'federal open market': 330,
#  'open market committee': 705,
#  'market committee met': 585,
#  'committee met indicates': 150,
#  'met indicates labor': 625,
#  'indicates labor market': 430,
#  'labor market continued': 535,
#  'market continued strengthen': 592,
#  'continued strengthen economic': 196,
#  'strengthen economic activity': 963,
#  'economic activity rising': 247,
#  'activity rising solid': 38,
#  'rising solid rate': 895,
#  'solid rate job': 926,
#  'rate job gains': 829,
#  'job gains strong': 519,
#  'gains strong average': 377,
#  'strong average recent': 969,
#  'average recent months': 68,
#  'recent months unemployment': 861,
#  'months unemployment rate': 667,
#  'unemployment rate declined': 1028,
#  'rate declined recent': 817,
#  'declined recent data': 219,
#  'recent data suggest': 856,
#  'data suggest growth': 202,
#  'suggest growth household': 984,
#  'growth household spending': 395,
#  'household spending picked': 406,
#  'spending picked business': 940,
#  'picked business fixed': 748,
#  'business fixed investment': 105,
#  'fixed investment continued': 336,
#  'investment continued grow': 484,
#  'continued grow strongly': 192,
#  'grow strongly 12': 390,
#  'strongly 12 month': 981,
#  '12 month basis': 2,
#  'month basis overall': 656,
#  'basis overall inflation': 94,
#  'overall inflation inflation': 717,
#  'inflation inflation items': 459,
#  'inflation items food': 461,
#  'items food energy': 503,
#  'food energy moved': 350,
#  'energy moved close': 276,
#  'moved close percent': 670,
#  'close percent indicators': 127,
#  'percent indicators longer': 733,
#  'indicators longer term': 435,
#  'longer term inflation': 553,
#  'term inflation expectations': 1008,
#  'inflation expectations little': 454,
#  'expectations little changed': 300,
#  'little changed balance': 548,
#  'changed balance consistent': 121,
#  'balance consistent statutory': 74,
#  'consistent statutory mandate': 187,
#  'statutory mandate committee': 956,
#  'mandate committee seeks': 572,
#  'committee seeks foster': 159,
#  'seeks foster maximum': 918,
#  'foster maximum employment': 353,
#  'maximum employment price': 600,
#  'employment price stability': 269,
#  'price stability committee': 775,
#  'stability committee expects': 943,
#  'committee expects gradual': 147,
#  'expects gradual increases': 325,
#  'gradual increases target': 387,
#  'increases target range': 427,
#  'target range federal': 1005,
#  'range federal funds': 800,
#  'federal funds rate': 328,
#  'funds rate consistent': 362,
#  'rate consistent sustained': 814,
#  'consistent sustained expansion': 189,
#  'sustained expansion economic': 994,
#  'expansion economic activity': 294,
#  'economic activity strong': 248,
#  'activity strong labor': 40,
#  'strong labor market': 976,
#  'labor market conditions': 534,
#  'market conditions inflation': 588,
#  'conditions inflation near': 174,
#  'inflation near committee': 463,
#  'near committee symmetric': 676,
#  'committee symmetric percent': 161,
#  'symmetric percent objective': 1002,
#  'percent objective medium': 743,
#  'objective medium term': 697,
#  'medium term risks': 612,
#  'term risks economic': 1014,
#  'risks economic outlook': 898,
#  'economic outlook appear': 253,
#  'outlook appear roughly': 708,
#  'appear roughly balanced': 59,
#  'roughly balanced view': 905,
#  'balanced view realized': 79,
#  'view realized expected': 1036,
#  'realized expected labor': 847,
#  'expected labor market': 311,
#  'conditions inflation committee': 173,
#  'inflation committee decided': 444,
#  'committee decided raise': 144,
#  'decided raise target': 214,
#  'raise target range': 793,
#  'funds rate percent': 367,
#  'rate percent stance': 833,
#  'percent stance monetary': 745,
#  'stance monetary policy': 953,
#  'monetary policy remains': 646,
#  'policy remains accommodative': 758,
#  'remains accommodative supporting': 887,
#  'accommodative supporting strong': 20,
#  'supporting strong labor': 988,
#  'market conditions sustained': 590,
#  'conditions sustained return': 181,
#  'sustained return percent': 996,
#  'return percent inflation': 890,
#  'percent inflation determining': 736,
#  'inflation determining timing': 449,
#  'determining timing size': 227,
#  'timing size future': 1025,
#  'size future adjustments': 921,
#  'future adjustments target': 370,
#  'adjustments target range': 50,
#  'funds rate committee': 361,
#  'rate committee assess': 812,
#  'committee assess realized': 137,
#  'assess realized expected': 62,
#  'realized expected economic': 846,
#  'expected economic conditions': 307,
#  'economic conditions relative': 251,
#  'conditions relative maximum': 176,
#  'relative maximum employment': 871,
#  'maximum employment objective': 598,
#  'employment objective symmetric': 265,
#  'objective symmetric percent': 699,
#  'symmetric percent inflation': 1001,
#  'percent inflation objective': 737,
#  'inflation objective assessment': 465,
#  'objective assessment account': 695,
#  'assessment account wide': 65,
#  'account wide range': 23,
#  'wide range information': 1047,
#  'range information including': 802,
#  'information including measures': 472,
#  'including measures labor': 416,
#  'measures labor market': 605,
#  'market conditions indicators': 587,
#  'conditions indicators inflation': 171,
#  'indicators inflation pressures': 433,
#  'inflation pressures inflation': 467,
#  'pressures inflation expectations': 769,
#  'inflation expectations readings': 455,
#  'expectations readings financial': 302,
#  'readings financial international': 843,
#  'financial international developments': 333,
#  'international developments voting': 481,
#  'developments voting fomc': 236,
#  'voting fomc monetary': 1041,
#  'fomc monetary policy': 345,
#  'monetary policy action': 644,
#  'policy action jerome': 754,
#  'action jerome powell': 30,
#  'jerome powell chairman': 514,
#  'powell chairman william': 761,
#  'chairman william dudley': 118,
#  'william dudley vice': 1050,
#  'dudley vice chairman': 242,
#  'vice chairman thomas': 1033,
#  'chairman thomas barkin': 116,
#  'thomas barkin raphael': 1019,
#  'barkin raphael bostic': 82,
#  'raphael bostic lael': 805,
#  'bostic lael brainard': 97,
#  'lael brainard loretta': 538,
#  'brainard loretta mester': 100,
#  'loretta mester randal': 557,
#  'mester randal quarles': 620,
#  'randal quarles john': 796,
#  'quarles john williams': 780,
#  'john williams implementation': 522,
#  'williams implementation note': 1053,
#  'implementation note issued': 413,
#  'note issued june': 688,
#  'issued june 13': 498,
#  'june 13 2018': 525,
#  'march': 576,
#  'moderate': 632,
#  'stayed': 957,
#  'low': 558,
#  'moderated': 639,
#  'fourth': 354,
#  'quarter': 783,
#  'pace': 718,
#  'based': 83,
#  'compensation': 162,
#  'remain': 876,
#  'survey': 989,
#  'expand': 286,
#  'run': 906,
#  'maintain': 565,
#  'objectives': 700,
#  'carefully': 106,
#  'monitor': 647,
#  'actual': 41,
#  'goal': 379,
#  'evolve': 280,
#  'manner': 573,
#  'warrant': 1042,
#  'likely': 543,
#  'time': 1020,
#  'levels': 540,
#  'prevail': 770,
#  'path': 725,
#  'depend': 222,
#  'informed': 475,
#  'incoming': 417,
#  'met march': 628,
#  'march indicates': 579,
#  'rising moderate': 892,
#  'moderate rate': 636,
#  'rate stayed': 834,
#  'stayed low': 958,
#  'low recent': 561,
#  'spending moderated': 937,
#  'moderated strong': 640,
#  'strong fourth': 970,
#  'fourth quarter': 355,
#  'quarter pace': 784,
#  'pace business': 719,
#  'percent market': 738,
#  'market based': 582,
#  'based measures': 84,
#  'measures inflation': 602,
#  'inflation compensation': 445,
#  'compensation remain': 165,
#  'remain low': 877,
#  'low survey': 563,
#  'survey based': 990,
#  'measures longer': 606,
#  'gradual adjustments': 383,
#  'adjustments stance': 47,
#  'policy economic': 755,
#  'activity expand': 34,
#  'expand moderate': 287,
#  'moderate pace': 633,
#  'pace medium': 723,
#  'term labor': 1009,
#  'conditions remain': 178,
#  'remain strong': 881,
#  'strong inflation': 972,
#  'inflation 12': 437,
#  'basis expected': 88,
#  'expected run': 316,
#  'run near': 909,
#  'decided maintain': 211,
#  'maintain target': 568,
#  'relative objectives': 872,
#  'objectives maximum': 701,
#  'employment percent': 266,
#  'inflation assessment': 441,
#  'developments committee': 231,
#  'committee carefully': 138,
#  'carefully monitor': 107,
#  'monitor actual': 648,
#  'actual expected': 42,
#  'expected inflation': 308,
#  'inflation developments': 450,
#  'developments relative': 233,
#  'relative symmetric': 874,
#  'symmetric inflation': 998,
#  'inflation goal': 456,
#  'goal committee': 380,
#  'expects economic': 321,
#  'conditions evolve': 168,
#  'evolve manner': 281,
#  'manner warrant': 574,
#  'warrant gradual': 1043,
#  'increases federal': 424,
#  'rate federal': 820,
#  'rate likely': 830,
#  'likely remain': 544,
#  'remain time': 883,
#  'time levels': 1021,
#  'levels expected': 541,
#  'expected prevail': 312,
#  'prevail longer': 771,
#  'longer run': 550,
#  'run actual': 907,
#  'actual path': 44,
#  'path federal': 726,
#  'rate depend': 818,
#  'depend economic': 223,
#  'outlook informed': 709,
#  'informed incoming': 476,
#  'incoming data': 418,
#  'data voting': 203,
#  'issued 2018': 492,
#  'committee met march': 152,
#  'met march indicates': 629,
#  'march indicates labor': 580,
#  'activity rising moderate': 37,
#  'rising moderate rate': 893,
#  'moderate rate job': 638,
#  'unemployment rate stayed': 1029,
#  'rate stayed low': 835,
#  'stayed low recent': 960,
#  'low recent data': 562,
#  'household spending moderated': 405,
#  'spending moderated strong': 938,
#  'moderated strong fourth': 641,
#  'strong fourth quarter': 971,
#  'fourth quarter pace': 356,
#  'quarter pace business': 785,
#  'pace business fixed': 720,
#  'close percent market': 128,
#  'percent market based': 739,
#  'market based measures': 583,
#  'based measures inflation': 85,
#  'measures inflation compensation': 603,
#  'inflation compensation remain': 447,
#  'compensation remain low': 166,
#  'remain low survey': 878,
#  'low survey based': 564,
#  'survey based measures': 991,
#  'based measures longer': 86,
#  'measures longer term': 607,
#  'expects gradual adjustments': 324,
#  'gradual adjustments stance': 384,
#  'adjustments stance monetary': 48,
#  'monetary policy economic': 645,
#  'policy economic activity': 756,
#  'economic activity expand': 246,
#  'activity expand moderate': 35,
#  'expand moderate pace': 288,
#  'moderate pace medium': 635,
#  'pace medium term': 724,
#  'medium term labor': 610,
#  'term labor market': 1010,
#  'market conditions remain': 589,
#  'conditions remain strong': 179,
#  'remain strong inflation': 882,
#  'strong inflation 12': 973,
#  'inflation 12 month': 438,
#  'month basis expected': 655,
#  'basis expected run': 91,
#  'expected run near': 317,
#  'run near committee': 910,
#  'committee decided maintain': 143,
#  'decided maintain target': 212,
#  'maintain target range': 569,
#  'conditions relative objectives': 177,
#  'relative objectives maximum': 873,
#  'objectives maximum employment': 702,
#  'maximum employment percent': 599,
#  'employment percent inflation': 267,
#  'percent inflation assessment': 735,
#  'inflation assessment account': 442,
#  'international developments committee': 480,
#  'developments committee carefully': 232,
#  'committee carefully monitor': 139,
#  'carefully monitor actual': 108,
#  'monitor actual expected': 649,
#  'actual expected inflation': 43,
#  'expected inflation developments': 309,
#  'inflation developments relative': 452,
#  'developments relative symmetric': 234,
#  'relative symmetric inflation': 875,
#  'symmetric inflation goal': 999,
#  'inflation goal committee': 457,
#  'goal committee expects': 381,
#  'committee expects economic': 146,
#  'expects economic conditions': 322,
#  'economic conditions evolve': 250,
#  'conditions evolve manner': 169,
#  'evolve manner warrant': 282,
#  'manner warrant gradual': 575,
#  'warrant gradual increases': 1044,
#  'gradual increases federal': 386,
#  'increases federal funds': 425,
#  'funds rate federal': 364,
#  'rate federal funds': 821,
#  'funds rate likely': 366,
#  'rate likely remain': 831,
#  'likely remain time': 545,
#  'remain time levels': 884,
#  'time levels expected': 1022,
#  'levels expected prevail': 542,
#  'expected prevail longer': 313,
#  'prevail longer run': 772,
#  'longer run actual': 551,
#  'run actual path': 908,
#  'actual path federal': 45,
#  'path federal funds': 727,
#  'funds rate depend': 363,
#  'rate depend economic': 819,
#  'depend economic outlook': 224,
#  'economic outlook informed': 254,
#  'outlook informed incoming': 710,
#  'informed incoming data': 477,
#  'incoming data voting': 419,
#  'data voting fomc': 204,
#  'note issued 2018': 685,
#  'january': 507,
#  'rates': 836,
#  'increased': 420,
#  'strengthened': 964,
#  'coming': 132,
#  'stabilize': 948,
#  'monitoring': 650,
#  'closely': 129,
#  '21': 14,
#  'met january': 626,
#  'january indicates': 510,
#  'strong recent': 977,
#  'growth rates': 396,
#  'rates household': 837,
#  'spending business': 933,
#  'investment moderated': 485,
#  'quarter readings': 786,
#  'readings 12': 840,
#  'energy continued': 271,
#  'continued run': 193,
#  'run percent': 911,
#  'compensation increased': 163,
#  'increased recent': 421,
#  'months remain': 662,
#  'stability economic': 944,
#  'outlook strengthened': 713,
#  'strengthened recent': 965,
#  'months committee': 658,
#  'expected coming': 304,
#  'coming months': 133,
#  'months stabilize': 664,
#  'stabilize committee': 949,
#  'committee percent': 156,
#  'term near': 1011,
#  'near term': 677,
#  'balanced committee': 76,
#  'committee monitoring': 154,
#  'monitoring inflation': 651,
#  'developments closely': 229,
#  'closely view': 130,
#  'issued march': 499,
#  'march 21': 577,
#  '21 2018': 15,
#  'committee met january': 151,
#  'met january indicates': 627,
#  'january indicates labor': 511,
#  'gains strong recent': 378,
#  'strong recent months': 978,
#  'suggest growth rates': 985,
#  'growth rates household': 397,
#  'rates household spending': 838,
#  'household spending business': 403,
#  'spending business fixed': 934,
#  'fixed investment moderated': 337,
#  'investment moderated strong': 486,
#  'fourth quarter readings': 357,
#  'quarter readings 12': 787,
#  'readings 12 month': 841,
#  'food energy continued': 348,
#  'energy continued run': 272,
#  'continued run percent': 194,
#  'run percent market': 912,
#  'inflation compensation increased': 446,
#  'compensation increased recent': 164,
#  'increased recent months': 422,
#  'recent months remain': 860,
#  'months remain low': 663,
#  'price stability economic': 776,
#  'stability economic outlook': 945,
#  'economic outlook strengthened': 255,
#  'outlook strengthened recent': 714,
#  'strengthened recent months': 966,
#  'recent months committee': 858,
#  'months committee expects': 659,
#  'basis expected coming': 89,
#  'expected coming months': 305,
#  'coming months stabilize': 134,
#  'months stabilize committee': 665,
#  'stabilize committee percent': 950,
#  'committee percent objective': 157,
#  'medium term near': 611,
#  'term near term': 1012,
#  'near term risks': 678,
#  'roughly balanced committee': 904,
#  'balanced committee monitoring': 77,
#  'committee monitoring inflation': 155,
#  'monitoring inflation developments': 652,
#  'inflation developments closely': 451,
#  'developments closely view': 230,
#  'closely view realized': 131,
#  'note issued march': 689,
#  'issued march 21': 500,
#  'march 21 2018': 578,
#  'december': 205,
#  '12â': 3,
#  'year': 1054,
#  '1â': 9,
#  'janet': 504,
#  'yellen': 1059,
#  'chair': 109,
#  '31': 16,
#  'met december': 622,
#  'december indicates': 208,
#  'rate gains': 822,
#  'gains employment': 372,
#  'employment household': 260,
#  'investment solid': 489,
#  'solid unemployment': 927,
#  'low 12': 559,
#  'pace labor': 721,
#  'inflation 12â': 439,
#  '12â month': 4,
#  'expected year': 318,
#  'year stabilize': 1057,
#  'rate 1â': 807,
#  '1â percent': 10,
#  'action janet': 27,
#  'janet yellen': 505,
#  'yellen chair': 1060,
#  'chair william': 110,
#  'mester jerome': 617,
#  'powell randal': 762,
#  'issued january': 495,
#  'january 31': 508,
#  '31 2018': 17,
#  'committee met december': 149,
#  'met december indicates': 623,
#  'december indicates labor': 209,
#  'solid rate gains': 925,
#  'rate gains employment': 823,
#  'gains employment household': 373,
#  'employment household spending': 261,
#  'fixed investment solid': 339,
#  'investment solid unemployment': 490,
#  'solid unemployment rate': 928,
#  'stayed low 12': 959,
#  'low 12 month': 560,
#  'moderate pace labor': 634,
#  'pace labor market': 722,
#  'strong inflation 12â': 974,
#  'inflation 12â month': 440,
#  '12â month basis': 5,
#  'basis expected year': 92,
#  'expected year stabilize': 319,
#  'year stabilize committee': 1058,
#  'funds rate 1â': 360,
#  'rate 1â percent': 808,
#  '1â percent stance': 11,
#  'policy action janet': 753,
#  'action janet yellen': 28,
#  'janet yellen chair': 506,
#  'yellen chair william': 1061,
#  'chair william dudley': 111,
#  'loretta mester jerome': 556,
#  'mester jerome powell': 618,
#  'jerome powell randal': 515,
#  'powell randal quarles': 763,
#  'note issued january': 687,
#  'issued january 31': 496,
#  'january 31 2018': 509,
#  'november': 690,
#  'averaging': 69,
#  'hurricane': 407,
#  'related': 864,
#  'fluctuations': 340,
#  'expanding': 289,
#  'quarters': 788,
#  'running': 913,
#  'disruptions': 237,
#  'rebuilding': 848,
#  'affected': 51,
#  'materially': 593,
#  'altered': 54,
#  'national': 671,
#  'economy': 256,
#  'consequently': 182,
#  'continues': 197,
#  'expect': 295,
#  'somewhat': 929,
#  'patrick': 728,
#  'harker': 398,
#  'robert': 899,
#  'kaplan': 526,
#  'charles': 122,
#  'evans': 277,
#  'neel': 680,
#  'kashkari': 529,
#  'preferred': 764,
#  'meeting': 613,
#  'existing': 283,
#  '2017': 12,
#  'met november': 630,
#  'november indicates': 691,
#  'rate averaging': 809,
#  'averaging hurricane': 70,
#  'hurricane related': 408,
#  'related fluctuations': 867,
#  'fluctuations job': 341,
#  'gains solid': 374,
#  'declined household': 216,
#  'spending expanding': 935,
#  'expanding moderate': 290,
#  'rate growth': 824,
#  'growth business': 392,
#  'investment picked': 487,
#  'picked recent': 749,
#  'recent quarters': 862,
#  'quarters 12': 789,
#  'energy declined': 273,
#  'declined year': 220,
#  'year running': 1055,
#  'running percent': 914,
#  'stability hurricane': 946,
#  'related disruptions': 865,
#  'disruptions rebuilding': 238,
#  'rebuilding affected': 849,
#  'affected economic': 52,
#  'activity employment': 32,
#  'employment inflation': 262,
#  'inflation recent': 468,
#  'months materially': 660,
#  'materially altered': 594,
#  'altered outlook': 55,
#  'outlook national': 711,
#  'national economy': 672,
#  'economy consequently': 257,
#  'consequently committee': 183,
#  'committee continues': 140,
#  'continues expect': 198,
#  'expect gradual': 296,
#  'expected remain': 314,
#  'remain somewhat': 879,
#  'somewhat percent': 930,
#  'percent near': 740,
#  'term stabilize': 1015,
#  'chairman lael': 113,
#  'brainard patrick': 101,
#  'patrick harker': 729,
#  'harker robert': 399,
#  'robert kaplan': 900,
#  'kaplan jerome': 527,
#  'quarles voting': 781,
#  'voting action': 1038,
#  'action charles': 25,
#  'charles evans': 123,
#  'evans neel': 278,
#  'neel kashkari': 681,
#  'kashkari preferred': 530,
#  'preferred meeting': 765,
#  'meeting maintain': 614,
#  'maintain existing': 566,
#  'existing target': 284,
#  'rate implementation': 826,
#  'issued december': 493,
#  'december 13': 206,
#  '13 2017': 7,
#  'committee met november': 153,
#  'met november indicates': 631,
#  'november indicates labor': 692,
#  'solid rate averaging': 924,
#  'rate averaging hurricane': 810,
#  'averaging hurricane related': 71,
#  'hurricane related fluctuations': 410,
#  'related fluctuations job': 868,
#  'fluctuations job gains': 342,
#  'job gains solid': 518,
#  'gains solid unemployment': 375,
#  'rate declined household': 816,
#  'declined household spending': 217,
#  'household spending expanding': 404,
#  'spending expanding moderate': 936,
#  'expanding moderate rate': 291,
#  'moderate rate growth': 637,
#  'rate growth business': 825,
#  'growth business fixed': 393,
#  'fixed investment picked': 338,
#  'investment picked recent': 488,
#  ...}

# %%
cosine_sims = linear_kernel(new_tokens, tfidf_vectorized)
cosine_sims
# Out:
# array([[0.90297468, 0.74575048, 0.67955391, 0.68107108, 0.57003126]])

# %%
euclid_dist = euclidean_distances(new_tokens, tfidf_vectorized)
euclid_dist
# Out:
# array([[0.44051179, 0.71309119, 0.80055742, 0.79866003, 0.92732814]])

# %%
# need to find the max tfid
tfidf_vectorized.shape
# Out:
# (5, 1062)

# %%
whos
# Out:
# Variable               Type                Data/Info
# ----------------------------------------------------
# CountVectorizer        type                <class 'sklearn.feature_e<...>on.text.CountVectorizer'>
# PorterStemmer          ABCMeta             <class 'nltk.stem.porter.PorterStemmer'>
# RegexpTokenizer        ABCMeta             <class 'nltk.tokenize.regexp.RegexpTokenizer'>
# SnowballStemmer        ABCMeta             <class 'nltk.stem.snowball.SnowballStemmer'>
# TfidfVectorizer        type                <class 'sklearn.feature_e<...>on.text.TfidfVectorizer'>
# WordNetLemmatizer      type                <class 'nltk.stem.wordnet.WordNetLemmatizer'>
# cosine_sims            ndarray             1x5: 5 elems, type `float64`, 40 bytes
# create_speech_dfs      function            <function create_speech_dfs at 0x10bbf5268>
# df                     DataFrame                    date            <...>eived since the Federa...
# doc_list               list                n=5
# euclid_dist            ndarray             1x5: 5 elems, type `float64`, 40 bytes
# euclidean_distances    function            <function euclidean_distances at 0x10b3867b8>
# h_df                   DataFrame                    date            <...>ce the Federal Open Ma...
# i                      int                 5
# linear_kernel          function            <function linear_kernel at 0x10b386d08>
# n_df                   DataFrame                   date             <...>ce the Federal Open Ma...
# n_speeches             int                 5
# new_text               Series              5    Information received<...>Name: text, dtype: object
# new_tokens             csr_matrix            (0, 1051)	0.03413847306<...>, 0)	0.028874101863603584
# np                     module              <module 'numpy' from '/an<...>kages/numpy/__init__.py'>
# os                     module              <module 'os' from '/anaco<...>da3/lib/python3.6/os.py'>
# pd                     module              <module 'pandas' from '/a<...>ages/pandas/__init__.py'>
# pickle                 module              <module 'pickle' from '/a<...>lib/python3.6/pickle.py'>
# stopwords              LazyCorpusLoader    <WordListCorpusReader in <...>pwords' (not loaded yet)>
# string                 module              <module 'string' from '/a<...>lib/python3.6/string.py'>
# tfidf_vectorized       ndarray             5x1062: 5310 elems, type `float64`, 42480 bytes
# tfidvect               TfidfVectorizer     TfidfVectorizer(analyzer=<...>n        vocabulary=None)
# this_date              Timestamp           2018-08-01 00:00:00
# transform_new_speech   function            <function transform_new_speech at 0x10bcde950>
# word_tokenize          function            <function word_tokenize at 0x10b7742f0>
