# %% [markdown]
# ### Importing Interest Rate Data

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import quandl
# %matplotlib inline

# %%
df = quandl.get("USTREASURY/YIELD", authtoken="zBYbsY7fujcHokgXQdsY")

# %%
from pandas.plotting import scatter_matrix

# %%
scatter_matrix(df, alpha = 0.4, figsize=(12,12))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1a1e55bf28>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1e62cf60>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1e4bf2e8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1e63ee10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1e6480b8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1e659320>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1e3bf588>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1e3e1828>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1e3e1860>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1e704cc0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1e725f28>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1e753240>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a1e77a7b8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1e7a4d30>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1e7d52e8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1e7fc860>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1e825dd8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1e856390>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1e87c908>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1e8a5e80>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1e8d7438>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1e8ff9b0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1e927f28>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1e9594e0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a1e982a58>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1e9a8fd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1e9d9588>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1ea00b00>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1ea330b8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1ea59630>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1ea81ba8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1eab3160>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1eada6d8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1eb03c50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1eb34208>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1eb5a780>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a1eb83cf8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1ebb32b0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1ebdb828>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1ec01da0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1ec35358>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1ec5c8d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1ec86e48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1ecb9400>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1ecde978>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1ed08ef0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1ed374a8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1ed5fa20>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a1ed88f98>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1edba550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1ede3ac8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1ee11080>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1ee375f8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1ee61b70>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1ee92128>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1eeb96a0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1eee2c18>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1ef141d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1ef3b748>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1ef63cc0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a1ef96278>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1efbc7f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1efe4d68>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1f015320>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1f03b898>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1f064e10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1f0963c8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1f0bf940>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1f0e7eb8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1f118470>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1f13d748>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1f167cc0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a1f199278>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1f1c17f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1f1e8d68>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1f219320>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1f242898>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1f269e10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1f2993c8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1f2c2940>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1f2eaeb8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1f31a470>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1f3429e8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1f36af60>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a1f39a518>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1f3c4a90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1f3f6048>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1f41d5c0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1f443b38>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1f4760f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1f49c668>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1f4c3be0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1f4f6198>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1f51d710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1f545c88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1f577240>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a1f59d7b8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1f5c6d30>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1f5f82e8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1f61e860>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1f648dd8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1f677390>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1f69f908>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1f6cae80>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1f6f9438>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1f7219b0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1f74af28>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1f7794e0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a1f7a1a58>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1f7cafd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1f7fb588>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1f822b00>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1f8540b8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1f87c630>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1f8a4ba8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1f8d5160>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1f8fd6d8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1f924c50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1f954208>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1f97d780>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a1f9a3cf8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1f9d62b0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1f9ff828>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1fa27da0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1fa57358>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1fa7e8d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1faa7e48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1fad7400>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1faff978>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1fb29ef0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1fb5a4a8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1fb80a20>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a1fbaaf98>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1fbd9550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1fc00ac8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1fc34080>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1fc5a5f8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1fc82b70>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1fcb4128>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1fcdd6a0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1fd03c18>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1fd351d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1fd5b748>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1fd83cc0>]],
#       dtype=object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 7310 entries, 1990-01-02 to 2019-03-21
# Data columns (total 12 columns):
# 1 MO     4411 non-null float64
# 2 MO     106 non-null float64
# 3 MO     7307 non-null float64
# 6 MO     7310 non-null float64
# 1 YR     7310 non-null float64
# 2 YR     7310 non-null float64
# 3 YR     7310 non-null float64
# 5 YR     7310 non-null float64
# 7 YR     7310 non-null float64
# 10 YR    7310 non-null float64
# 20 YR    6371 non-null float64
# 30 YR    6316 non-null float64
# dtypes: float64(12)
# memory usage: 742.4 KB

# %%
X = df.copy()

# %% [markdown]
# ## Interesting questions
# Do I need to  express these in terms of forward rates instead of levels?
# It would make more sense having it be the market's expected path of interest rates rather than some mutted average.
#
# I will just need to remember to transform the data back into yields for the course of prediction
#
# Maybe start a pipeline document that explains the entire process

# %% [markdown]
# ## To Be Done
# Set up web scraping to get a mongoDB goind with the different Fed Speaches
# Detemine how to handle the video of speaches
# Make sure I map the speaker to the process and the type of speach {transcript, remarks, presentation}

# %% [markdown]
# ## Interesting extensions
# Which type of press release is more important
# Which speakers are more important
# Which speakers are least similar to actual FOMC documents
# Any way to plot  a history of the cosine similary between speakers with their faces on it for an app?
# Maybe a timeline of the speaches and their impact?

# %% [markdown]
# ## Additional variables to consider for the project
# Currency rates cut before the speaches - to control for .....
# Economic releases that may have also been impactful for the period
# Time before new press release
# When the dot plots get released
#
# Short term interest rates

# %% [markdown]
# 2019-03-19  2.46  2.52  2.50  2.46  2.42  2.42  2.51   2.61
# 2019-03-20  2.48  2.49  2.47  2.40  2.34  2.34  2.44   2.54
# 2019-03-21  2.49  2.50  2.48  2.41  2.34  2.34  2.44   2.54
#
# [7310 rows x 8 columns]>

# %%
X.describe()
# Out:
#               3 MO         6 MO         1 YR         2 YR         3 YR  \
# count  7307.000000  7310.000000  7310.000000  7310.000000  7310.000000
# mean      2.799869     2.936088     3.070078     3.385984     3.612397
# std       2.310712     2.342484     2.336510     2.345854     2.282790
# min       0.000000     0.020000     0.080000     0.160000     0.280000
# 25%       0.270000     0.430000     0.580000     0.970000     1.410000
# 50%       2.740000     2.885000     2.990000     3.355000     3.700000
# 75%       5.040000     5.150000     5.210000     5.470000     5.600000
# max       8.260000     8.490000     8.640000     9.050000     9.110000
#
#               5 YR         7 YR        10 YR
# count  7310.000000  7310.000000  7310.000000
# mean      4.021665     4.335365     4.577570
# std       2.142401     2.033970     1.907475
# min       0.560000     0.910000     1.370000
# 25%       1.980000     2.432500     2.850000
# 50%       4.045000     4.310000     4.490000
# 75%       5.807500     6.010000     6.020000
# max       9.100000     9.120000     9.090000

# %%
X.plot(figsize=(15,15), title = 'Historical US Treasury Yield Curve', grid=True)

# %% [markdown]
# ## Interesting things to describe
# Is there a better way to do this in 3D?
# Is there possible way to do this as a video showing the term structure over time being simulated
#
# ## ALSO
# Would be interesting to build a Spark Database that shows the yeild curve evolving and the shocks to the principal components below the curve.!!!

# %% [markdown]
# ### Thought about model
# Show latest fed speaches and most common words that are not common in the corpus
# Then show the model's forecasted shock to the eighenvectoers
# Then show the actual result
#
# #Picture this
# Select a Fed Speach that occured recentlty
# -highlight how different it is from the last Fed speach
# -highlight how different it is from the last Federal press conference
# -show the model's forecast for interest rates due to this response (maybe include FX rates impact)
# -show the actual results
# -classify the goodness of fit
#
# Also possibly classify the goodness of fit for the lagged model

# %%
# BELOW IS MASSIVE IMPORT OF CRAP FROM PCA LECTURE

# %%
from numpy.linalg import svd, eig
import matplotlib.pyplot as plt
import matplotlib.patches as patches
from matplotlib import cm
from sklearn.datasets import load_iris, fetch_olivetti_faces
from sklearn.decomposition import PCA
from pandas.plotting import scatter_matrix

# %%
plt.plot(X['3 MO'])

# %%
n_comp = 5
test = PCA(n_components = n_comp, random_state=44)

# %%
X1 = X.drop(['3 MO'], axis =1)

# %%
test.fit(X1)
# Out:
# PCA(copy=True, iterated_power='auto', n_components=5, random_state=44,
#   svd_solver='auto', tol=0.0, whiten=False)

# %%
print("Explained variance: ", test.explained_variance_ratio_)
# Out:
# Explained variance:  [9.70773604e-01 2.75797196e-02 1.36256707e-03 1.75701901e-04
#  5.40826103e-05]

# %%
plt_x = np.arange(0, n_comp)
plt.bar(plt_x, test.explained_variance_ratio_)
# Out:
# <BarContainer object of 5 artists>

# %%
print("PCA singular values: ", test.singular_values_)
# Out:
# PCA singular values:  [491.35314077  82.81894236  18.40830077   6.61032765   3.66744475]

# %% [markdown]
# ### NEED TO LEARN HOW TO RETURN THE HISTORICAL SHOCKS TO THESE
# I am sure there is a method to return these
#
# When we have these,
# PLOT THE PRINCIPAL COMPONENT SHOCKS OVER TIME (After normalizing so we can see them)
# DO AUTOCORRELATIONS - these should be orthodignal to each other by contstu
