# %%
# testing import
import pickle
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
# %config InlineBackend.figure_format='retina'
import seaborn as sns
sns.set(style='white', palette='muted', color_codes = True)

# %%
results = pickle.load(open("../data/initial_distrib", "rb" ) )

# %%
results
# Out:
# [array([[ 1.75356616e-05,  2.64040499e-05,  4.29946664e-04, ...,
#           6.16888082e-04, -5.04218346e-05,  5.71192064e-04],
#         [ 1.75397732e-05,  1.83241584e-05,  4.57228036e-04, ...,
#           8.69957284e-04,  5.24179123e-04,  5.34284817e-04],
#         [-8.24796351e-05,  5.19468559e-04,  5.54324359e-05, ...,
#          -8.42504156e-06, -2.77242295e-04, -3.32022101e-04],
#         ...,
#         [ 6.76471146e-06,  2.36205864e-04, -8.65787540e-04, ...,
#          -5.66381395e-04, -3.93756665e-04, -3.33118856e-05],
#         [-8.79570130e-05, -7.88905669e-05,  5.14010835e-04, ...,
#           4.66638914e-04,  6.67263403e-04,  4.81872652e-05],
#         [ 1.82628223e-05,  7.62782474e-06, -1.92516901e-04, ...,
#           3.72488338e-07, -2.58754715e-04,  7.56264005e-05]]),
#  array([[ 2.43515038e-05,  2.46626145e-05,  4.41902245e-04, ...,
#           6.28007283e-04, -4.08335341e-05,  5.76254169e-04],
#         [-1.22838438e-05, -2.02134261e-05,  3.95268751e-04, ...,
#           8.10720911e-04,  5.07694881e-04,  5.06355849e-04],
#         [-7.56638701e-05,  5.25968776e-04,  6.76752744e-05, ...,
#           3.03726626e-06, -2.79253079e-04, -3.26601484e-04],
#         ...,
#         [-1.60535372e-05,  1.84894325e-04, -9.25859046e-04, ...,
#          -6.35145386e-04, -4.38211864e-04, -6.84643728e-05],
#         [-8.27000128e-05, -8.42226615e-05,  4.34603966e-04, ...,
#           4.78560894e-04,  6.81207785e-04,  5.46627995e-05],
#         [ 1.73345254e-05,  1.63895887e-05, -1.32932653e-04, ...,
#           1.28680409e-05, -2.69271418e-04,  7.98696240e-05]]),
#  array([[ 1.85504745e-05,  1.75460091e-05,  4.17479495e-04, ...,
#           6.17918330e-04, -4.42033423e-05,  5.83741576e-04],
#         [ 1.85424752e-05,  1.75384429e-05,  4.17419865e-04, ...,
#           8.45442045e-04,  5.24560547e-04,  5.25202588e-04],
#         [-8.14655172e-05,  5.18849207e-04,  1.44096891e-05, ...,
#          -4.22268624e-05, -2.82563845e-04, -3.40234553e-04],
#         ...,
#         [ 1.23755334e-05,  2.12873364e-04, -8.98454562e-04, ...,
#          -5.77120795e-04, -4.11139483e-04, -3.71971702e-05],
#         [-8.76288660e-05, -8.90450083e-05,  5.14647394e-04, ...,
#           4.88279209e-04,  6.76302646e-04,  4.91606534e-05],
#         [ 1.24022743e-05,  1.15641353e-05, -1.91881657e-04, ...,
#          -1.76484420e-05, -2.74132056e-04,  7.43725902e-05]]),
#  array([[-3.49715506e-06, -1.59598001e-05,  3.59456598e-04, ...,
#           6.02439446e-04, -1.52961996e-05,  5.67174986e-04],
#         [-1.27103786e-05,  8.21535248e-06,  4.62815802e-04, ...,
#           8.56594097e-04,  4.64709208e-04,  5.87183725e-04],
#         [-9.73767305e-05,  5.14719909e-04,  3.99368485e-05, ...,
#          -1.56536863e-05, -2.76918750e-04, -3.11264866e-04],
#         ...,
#         [ 2.90720152e-06,  2.07494561e-04, -8.92261236e-04, ...,
#          -5.54938145e-04, -3.85654046e-04, -1.96836066e-05],
#         [-1.00608271e-04, -1.02642277e-04,  4.97687785e-04, ...,
#           4.67565842e-04,  6.55265895e-04,  2.92977938e-05],
#         [ 1.83543714e-06,  3.34875593e-06, -1.94562291e-04, ...,
#          -1.40027056e-05, -2.69439305e-04,  7.46617294e-05]]),
#  array([[ 7.27492088e-06,  2.06679212e-06,  3.90774253e-04, ...,
#           6.07653204e-04, -3.06888392e-05,  5.51222669e-04],
#         [-2.39554115e-05, -1.98711968e-05,  3.95818864e-04, ...,
#           8.09064900e-04,  4.53580799e-04,  5.55022151e-04],
#         [-9.91023443e-05,  5.13206770e-04,  3.88755476e-05, ...,
#          -2.04655585e-05, -2.85373623e-04, -3.11363974e-04],
#         ...,
#         [ 1.14943731e-05,  1.82551027e-04, -1.01364981e-03, ...,
#          -6.34303384e-04, -3.69350539e-04, -1.19584158e-04],
#         [-8.53070791e-05, -9.86200978e-05,  4.65403007e-04, ...,
#           4.64125864e-04,  7.00872710e-04, -5.81413110e-06],
#         [ 6.51266288e-06,  8.41774929e-06, -1.89753960e-04, ...,
#          -3.39415456e-06, -2.52980034e-04,  7.57656246e-05]]),
#  array([[-1.82681103e-21, -3.40565953e-21,  4.02363071e-04, ...,
#           6.08012229e-04, -5.21684216e-05,  5.74806327e-04],
#         [ 2.74345203e-21,  3.90364557e-21,  4.02483467e-04, ...,
#           8.35802402e-04,  5.16576406e-04,  5.16519061e-04],
#         [-1.00000000e-04,  5.01318323e-04, -3.46786525e-07, ...,
#          -5.15020903e-05, -2.90321882e-04, -3.48691699e-04],
#         ...,
#         [-8.55960962e-22,  2.01265198e-04, -9.08232370e-04, ...,
#          -5.83246794e-04, -4.16111028e-04, -4.31723001e-05],
#         [-1.00000000e-04, -1.00577500e-04,  5.04550192e-04, ...,
#           4.81948048e-04,  6.71184944e-04,  4.31723001e-05],
#         [-7.79408516e-22, -7.36754731e-22, -2.01795971e-04, ...,
#          -2.38060852e-05, -2.79009423e-04,  6.84017069e-05]])]

# %%
results = pickle.load(open("../data/fwd_cv_data", "rb" ) )

# %%
forwards.head()
# Out:
#              six_m     one_y     two_y   three_y    five_y   seven_y  \
# Date
# 2015-04-08  0.0010  0.003404  0.008825  0.015172  0.021082  0.025724
# 2015-04-09  0.0010  0.003404  0.009227  0.015677  0.021918  0.026240
# 2015-04-10  0.0009  0.003905  0.009227  0.016081  0.021867  0.025950
# 2015-04-13  0.0011  0.003504  0.008724  0.016082  0.021411  0.026002
# 2015-04-14  0.0010  0.003604  0.008523  0.015072  0.020981  0.025622
#
#                ten_y  d_six_m   d_one_y       d_two_y  d_three_y  d_five_y  \
# Date
# 2015-04-08  0.025482   0.0000  0.000000  4.023631e-04  -0.000102  0.000608
# 2015-04-09  0.025999   0.0000  0.000000  4.024835e-04   0.000505  0.000836
# 2015-04-10  0.025650  -0.0001  0.000501 -3.467865e-07   0.000404 -0.000052
# 2015-04-13  0.025448   0.0002 -0.000401 -5.029008e-04   0.000001 -0.000456
# 2015-04-14  0.025009  -0.0001  0.000100 -2.011765e-04  -0.001011 -0.000430
#
#             d_seven_y   d_ten_y   ed_last  ed_avg_n  cos_last  cos_avg_n
# Date
# 2015-04-08  -0.000052  0.000575  1.173013  1.173013  0.296845   0.296845
# 2015-04-09   0.000517  0.000517  0.000000  0.000000  0.000000   0.000000
# 2015-04-10  -0.000290 -0.000349  0.000000  0.000000  0.000000   0.000000
# 2015-04-13   0.000052 -0.000203  0.000000  0.000000  0.000000   0.000000
# 2015-04-14  -0.000380 -0.000439  0.000000  0.000000  0.000000   0.000000

# %%
# initial results
X = forwards[['d_six_m', 'd_one_y', 'd_two_y', 'd_three_y', 'd_five_y', 'd_seven_y', 'd_ten_y']].values
X.shape
# Out:
# (497, 7)

# %%
plt.hist(results[0][:,0])
# Out:
# (array([  1.,  10.,  26., 131., 213.,  66.,  45.,   3.,   1.,   1.]),
#  array([-7.68277363e-04, -5.89983172e-04, -4.11688981e-04, -2.33394790e-04,
#         -5.51005987e-05,  1.23193592e-04,  3.01487784e-04,  4.79781975e-04,
#          6.58076166e-04,  8.36370357e-04,  1.01466455e-03]),
#  <a list of 10 Patch objects>)

# %%
fig, axs = plt.subplots(1, 1, figsize = (10,10))
fig.suptitle('Model Distributions', fontsize=24)
# axs[0,0].set_title('ARIMA Model error 6 month forward rate')
#temp = results[0][:,3]
sns.distplot(results[0][:,0], hist=False, color = 'red', kde_kws={'shade': True}, label='ARIMA')
sns.distplot(results[1][:,0], hist=False, color = 'blue', kde_kws={'shade': True},  label='ARIMAX')
sns.distplot(results[3][:,0], hist=False, color = 'black', kde_kws={'shade': True},  label='PCA ARIMA')
sns.distplot(results[4][:,0], hist=False, color = 'yellow', kde_kws={'shade': True}, label='PCA ARIMAX')
sns.distplot(X[:,0], hist=False, color = 'purple', kde_kws={'shade': True},  label='Actual')
plt.grid()


# sns.distplot(X[:,0], hist=False, color = 'black', kde_kws={'shade': True}, ax=axs[0,1], label='Actual daily change')

# axs[0,1].set_title('Distribution of ARIMA Model for 6M forward rate')


# axs[1,0].plot(dist_list[0][:,1])
# axs[1,0].set_title('ARIMA error 1 year forward rate')
# sns.distplot(dist_list[0][:,1], hist=False, color = 'red', kde_kws={'shade': True}, ax=axs[1,1], label = 'ARIMA')
# sns.distplot(X[:,1], hist=False, color = 'black', kde_kws={'shade': True}, ax=axs[1,1], label='Actual daily change')
#axs[1,1].set_title('Distribution of ARIMA Model for 1Y forward rate')

# %%
fig, axs = plt.subplots(1, 1, figsize = (10,10))
fig.suptitle('Model Distributions', fontsize=24)
# axs[0,0].set_title('ARIMA Model error 6 month forward rate')
#temp = results[0][:,3]
sns.distplot(results[0][:,1], hist=False, color = 'red', kde_kws={'shade': True}, label='ARIMA')
sns.distplot(results[1][:,1], hist=False, color = 'blue', kde_kws={'shade': True},  label='ARIMAX')
sns.distplot(results[3][:,1], hist=False, color = 'black', kde_kws={'shade': True},  label='PCA ARIMA')
sns.distplot(results[4][:,1], hist=False, color = 'yellow', kde_kws={'shade': True}, label='PCA ARIMAX')
sns.distplot(X[:,1], hist=False, color = 'purple', kde_kws={'shade': True},  label='Actual')
plt.grid()

# %%
fig, axs = plt.subplots(1, 1, figsize = (10,10))
fig.suptitle('Model Distributions', fontsize=24)
# axs[0,0].set_title('ARIMA Model error 6 month forward rate')
#temp = results[0][:,3]
sns.distplot(results[0][:,2], hist=False, color = 'red', kde_kws={'shade': True}, label='ARIMA')
sns.distplot(results[1][:,2], hist=False, color = 'blue', kde_kws={'shade': True},  label='ARIMAX')
sns.distplot(results[3][:,2], hist=False, color = 'black', kde_kws={'shade': True},  label='PCA ARIMA')
sns.distplot(results[4][:,2], hist=False, color = 'yellow', kde_kws={'shade': True}, label='PCA ARIMAX')
sns.distplot(X[:,2], hist=False, color = 'purple', kde_kws={'shade': True},  label='Actual')
plt.grid()

# %%
fig, axs = plt.subplots(1, 1, figsize = (10,10))
fig.suptitle('Model Distributions', fontsize=24)
# axs[0,0].set_title('ARIMA Model error 6 month forward rate')
#temp = results[0][:,3]
sns.distplot(results[0][:,3], hist=False, color = 'red', kde_kws={'shade': True}, label='ARIMA')
sns.distplot(results[1][:,3], hist=False, color = 'blue', kde_kws={'shade': True},  label='ARIMAX')
sns.distplot(results[3][:,3], hist=False, color = 'black', kde_kws={'shade': True},  label='PCA ARIMA')
sns.distplot(results[4][:,3], hist=False, color = 'yellow', kde_kws={'shade': True}, label='PCA ARIMAX')
sns.distplot(X[:,3], hist=False, color = 'purple', kde_kws={'shade': True},  label='Actual')
plt.grid()

# %%
fig, axs = plt.subplots(1, 1, figsize = (10,10))
fig.suptitle('Model Distributions', fontsize=24)
# axs[0,0].set_title('ARIMA Model error 6 month forward rate')
#temp = results[0][:,3]
sns.distplot(results[0][:,4], hist=False, color = 'red', kde_kws={'shade': True}, label='ARIMA')
sns.distplot(results[1][:,4], hist=False, color = 'blue', kde_kws={'shade': True},  label='ARIMAX')
sns.distplot(results[3][:,4], hist=False, color = 'black', kde_kws={'shade': True},  label='PCA ARIMA')
sns.distplot(results[4][:,4], hist=False, color = 'yellow', kde_kws={'shade': True}, label='PCA ARIMAX')
sns.distplot(X[:,4], hist=False, color = 'purple', kde_kws={'shade': True},  label='Actual')
plt.grid()

# %%
fig, axs = plt.subplots(1, 1, figsize = (10,10))
fig.suptitle('Model Distributions', fontsize=24)
# axs[0,0].set_title('ARIMA Model error 6 month forward rate')
#temp = results[0][:,3]
sns.distplot(results[0][:,5], hist=False, color = 'red', kde_kws={'shade': True}, label='ARIMA')
sns.distplot(results[1][:,5], hist=False, color = 'blue', kde_kws={'shade': True},  label='ARIMAX')
sns.distplot(results[3][:,5], hist=False, color = 'black', kde_kws={'shade': True},  label='PCA ARIMA')
sns.distplot(results[4][:,5], hist=False, color = 'yellow', kde_kws={'shade': True}, label='PCA ARIMAX')
sns.distplot(X[:,5], hist=False, color = 'purple', kde_kws={'shade': True},  label='Actual')
plt.grid()

# %%
fig, axs = plt.subplots(1, 1, figsize = (10,10))
fig.suptitle('Model Distributions', fontsize=24)
# axs[0,0].set_title('ARIMA Model error 6 month forward rate')
#temp = results[0][:,3]
sns.distplot(results[0][:,6], hist=False, color = 'red', kde_kws={'shade': True}, label='ARIMA')
sns.distplot(results[1][:,6], hist=False, color = 'blue', kde_kws={'shade': True},  label='ARIMAX')
sns.distplot(results[3][:,6], hist=False, color = 'black', kde_kws={'shade': True},  label='PCA ARIMA')
sns.distplot(results[4][:,6], hist=False, color = 'yellow', kde_kws={'shade': True}, label='PCA ARIMAX')
sns.distplot(X[:,6], hist=False, color = 'purple', kde_kws={'shade': True},  label='Actual')
plt.grid()

# %%
def print_mean_summary(results, mean, index):
    print("Means for the six month forward rate")
    print('This is the mean of the results model one' , np.mean(results[0][:,index]))
    print('This is the mean of the results model two' , np.mean(results[1][:,index]))
    print('This is the mean of the results model three', np.mean(results[2][:,index]))
    print('This is the mean of the results model four', np.mean(results[3][:,index]))
    print('This is the mean of the results model five', np.mean(results[4][:,index]))
    print('This is the mean of the results model six', np.mean(results[5][:,index]))
    print('This is the actual mean of the forwards', np.mean(X[:,index]))

# %%
print_mean_summary(results, X, 0)
# Out:
# Means for the six month forward rate
# This is the mean of the results model one 3.055349213166725e-05
# This is the mean of the results model two 3.241450335947434e-05
# This is the mean of the results model three 3.200116845898058e-05
# This is the mean of the results model four 1.6455526043871885e-05
# This is the mean of the results model five 1.636253588634092e-05
# This is the mean of the results model six 1.629778672032193e-05
# This is the actual mean of the forwards 1.629778672032193e-05

# %%
print_mean_summary(results, X, 1)
# Out:
# Means for the six month forward rate
# This is the mean of the results model one 3.219346620092741e-05
# This is the mean of the results model two 3.220198055458551e-05
# This is the mean of the results model three 3.084994229432822e-05
# This is the mean of the results model four 1.68406804787379e-05
# This is the mean of the results model five 1.6883206778625754e-05
# This is the mean of the results model six 1.6358495968846272e-05
# This is the actual mean of the forwards 1.6358495968846272e-05

# %%
print_mean_summary(results, X, 2)
# Out:
# Means for the six month forward rate
# This is the mean of the results model one 2.9868274591543415e-05
# This is the mean of the results model two 3.0907183755208356e-05
# This is the mean of the results model three 2.646896275662931e-05
# This is the mean of the results model four 1.5406439886775576e-05
# This is the mean of the results model five 1.5753211489077752e-05
# This is the mean of the results model six 1.3962163762567828e-05
# This is the actual mean of the forwards 1.3962163762567828e-05

# %%
print_mean_summary(results, X, 3)
# Out:
# Means for the six month forward rate
# This is the mean of the results model one 1.965642984399682e-05
# This is the mean of the results model two 2.262992969823361e-05
# This is the mean of the results model three 1.9594595563544976e-05
# This is the mean of the results model four 1.0836339557586363e-05
# This is the mean of the results model five 1.038144544052968e-05
# This is the mean of the results model six 9.116303891886218e-06
# This is the actual mean of the forwards 9.116303891886218e-06

# %%
print_mean_summary(results, X, 4)
# Out:
# Means for the six month forward rate
# This is the mean of the results model one 2.066692863549546e-05
# This is the mean of the results model two 2.2550822596064167e-05
# This is the mean of the results model three 1.9911533988616765e-05
# This is the mean of the results model four 1.3826126030694835e-05
# This is the mean of the results model five 1.357301366819965e-05
# This is the mean of the results model six 1.128959608592839e-05
# This is the actual mean of the forwards 1.128959608592839e-05

# %%
print_mean_summary(results, X, 5)
# Out:
# Means for the six month forward rate
# This is the mean of the results model one 1.5959353298241974e-05
# This is the mean of the results model two 1.658768267440467e-05
# This is the mean of the results model three 1.5623394998504905e-05
# This is the mean of the results model four 1.1545190985391104e-05
# This is the mean of the results model five 1.072105473705941e-05
# This is the mean of the results model six 8.972100360879571e-06
# This is the actual mean of the forwards 8.972100360879571e-06

# %%
print_mean_summary(results, X, 6)
# Out:
# Means for the six month forward rate
# This is the mean of the results model one 1.5754297584800306e-05
# This is the mean of the results model two 1.6496219481983473e-05
# This is the mean of the results model three 1.5494430367913325e-05
# This is the mean of the results model four 1.039689478666248e-05
# This is the mean of the results model five 1.0266850899870053e-05
# This is the mean of the results model six 8.00451088082242e-06
# This is the actual mean of the forwards 8.00451088082242e-06

# %%
whos
# Out:
# Variable             Type           Data/Info
# ---------------------------------------------
# X                    ndarray        497x7: 3479 elems, type `float64`, 27832 bytes
# axs                  AxesSubplot    AxesSubplot(0.125,0.125;0.775x0.755)
# fig                  Figure         Figure(720x720)
# forwards             DataFrame                   six_m     on<...>\n[497 rows x 18 columns]
# np                   module         <module 'numpy' from '/an<...>kages/numpy/__init__.py'>
# pickle               module         <module 'pickle' from '/a<...>lib/python3.6/pickle.py'>
# plt                  module         <module 'matplotlib.pyplo<...>es/matplotlib/pyplot.py'>
# print_mean_summary   function       <function print_mean_summary at 0x1a19672598>
# results              list           n=6
# sns                  module         <module 'seaborn' from '/<...>ges/seaborn/__init__.py'>
# temp                 ndarray        497: 497 elems, type `float64`, 3976 bytes

# %%
forwards.describe()
# Out:
#             six_m       one_y       two_y     three_y      five_y     seven_y  \
# count  497.000000  497.000000  497.000000  497.000000  497.000000  497.000000
# mean     0.003953    0.007129    0.011550    0.015855    0.021361    0.027189
# std      0.002099    0.002214    0.002499    0.003531    0.004125    0.003965
# min      0.000500    0.003403    0.007013    0.008720    0.013098    0.018210
# 25%      0.002300    0.005307    0.009730    0.012542    0.017332    0.023634
# 50%      0.004300    0.006913    0.010831    0.015981    0.021833    0.028220
# 75%      0.005000    0.008620    0.012951    0.018697    0.025047    0.030532
# max      0.009300    0.012037    0.017684    0.022944    0.028853    0.034434
#
#             ten_y     d_six_m     d_one_y     d_two_y   d_three_y    d_five_y  \
# count  497.000000  497.000000  497.000000  497.000000  497.000000  497.000000
# mean     0.026408    0.000016    0.000016    0.000014    0.000009    0.000011
# std      0.003724    0.000196    0.000365    0.000551    0.000635    0.000621
# min      0.018246   -0.000800   -0.001506   -0.002012   -0.002012   -0.002007
# 25%      0.023498   -0.000100   -0.000201   -0.000303   -0.000405   -0.000430
# 50%      0.027688    0.000000    0.000000    0.000000    0.000000    0.000000
# 75%      0.029433    0.000100    0.000201    0.000402    0.000503    0.000407
# max      0.032752    0.001000    0.001708    0.001813    0.001816    0.002655
#
#         d_seven_y     d_ten_y     ed_last    ed_avg_n    cos_last   cos_avg_n
# count  497.000000  497.000000  497.000000  497.000000  497.000000  497.000000
# mean     0.000009    0.000008    0.163054    0.163155    0.031647    0.031542
# std      0.000691    0.000575    0.417566    0.417792    0.084224    0.083764
# min     -0.002510   -0.001964    0.000000    0.000000    0.000000    0.000000
# 25%     -0.000416   -0.000372    0.000000    0.000000    0.000000    0.000000
# 50%      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 75%      0.000469    0.000338    0.000000    0.000000    0.000000    0.000000
# max      0.003046    0.002071    1.330989    1.326005    0.373948    0.373948

# %%
pickle_out = open('../data/Monday_results', 'wb')
pickle.dump(results, pickle_out)
pickle_out.close()
