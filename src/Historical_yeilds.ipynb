# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# %matplotlib inline
import seaborn as sns

# %%
pwd
# Out:
# '/Users/davidsmith/Documents/Galvanize/Capstone/src'

# %%
df = pd.read_excel('../data/Historical_yields.xlsx')

# %%
df.head()
# Out:
#          Date  1 MO  2 MO  3 MO  6 MO  1 YR  2 YR  3 YR  5 YR  7 YR  10 YR  \
# 0  2019-04-09  2.42  2.43  2.42  2.46  2.42  2.35  2.31  2.31  2.40   2.51
# 1  2019-04-08  2.43  2.44  2.43  2.48  2.43  2.36  2.31  2.33  2.42   2.52
# 2  2019-04-05  2.42  2.43  2.44  2.46  2.43  2.35  2.30  2.31  2.40   2.50
# 3  2019-04-04  2.43  2.43  2.44  2.46  2.41  2.33  2.29  2.32  2.41   2.51
# 4  2019-04-03  2.42  2.43  2.44  2.45  2.41  2.33  2.29  2.32  2.42   2.52
#
#    20 YR  30 YR
# 0   2.73   2.92
# 1   2.74   2.93
# 2   2.72   2.91
# 3   2.74   2.92
# 4   2.75   2.93

# %%
start_date = '2013-01-01'
end_date = '2013-12-31'

df_small = df[df['Date']> start_date]

# %%
df_small = df_small[df_small['Date']<end_date]

# %%
df_small.describe()
# Out:
#              1 MO  2 MO        3 MO        6 MO        1 YR        2 YR  \
# count  249.000000   0.0  249.000000  249.000000  249.000000  249.000000
# mean     0.046426   NaN    0.057028    0.088273    0.131165    0.306787
# std      0.042299   NaN    0.025464    0.023568    0.017199    0.059114
# min      0.000000   NaN    0.000000    0.020000    0.090000    0.200000
# 25%      0.020000   NaN    0.040000    0.080000    0.120000    0.260000
# 50%      0.040000   NaN    0.050000    0.090000    0.130000    0.300000
# 75%      0.060000   NaN    0.070000    0.110000    0.140000    0.340000
# max      0.320000   NaN    0.140000    0.160000    0.170000    0.520000
#
#              3 YR        5 YR        7 YR       10 YR       20 YR       30 YR
# count  249.000000  249.000000  249.000000  249.000000  249.000000  249.000000
# mean     0.541888    1.169759    1.734659    2.347390    3.115863    3.444096
# std      0.156898    0.340531    0.419516    0.412395    0.386850    0.336458
# ...

# %%
df_small.sort_values(by='Date', axis=0, ascending=True, inplace=True, kind='quicksort', na_position='last')

# %%
f, ax = plt.subplots(1,1, figsize=(10,10))
ax.plot(df_small['Date'], df_small['10 YR'], label = '10 YR')
ax.plot(df_small['Date'], df_small['5 YR'], label='5 YR')
ax.xaxis.set_major_locator(plt.MaxNLocator(4))
#ax.legend()
ax.axvline(x=date_tantrum1, ymin=0, ymax=3, color = 'black', label='Taper Speech')
#ax.axvline(x=date_tantrum2, ymin=0, ymax=3, color = 'black')
ax.set_title('5 and 10 Year US Treasury Interest Rates 2013', fontsize=16)
ax.grid()
ax.legend()
ax.set_facecolor('whitesmoke')
#N = 5
#ymin, ymax = ax.get_ylim()
#ax.set_yticks(np.round(np.linspace(ymin, ymax, N), 2))
plt.savefig('taper_tantrum.png')

# %%
date_tantrum1 = '2013-05-22'
date_tantrum2 = '2013-07-19'
