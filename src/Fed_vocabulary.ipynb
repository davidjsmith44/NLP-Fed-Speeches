# %%
# working with wordcloud
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
import pickle

# %%
tfidf = pickle.load(open('fed_speech_vocab', 'rb'))

# %%
tfidf
# Out:
# TfidfVectorizer(analyzer='word', binary=False, decode_error='strict',
#         dtype=<class 'numpy.float64'>, encoding='utf-8', input='content',
#         lowercase=True, max_df=1.0, max_features=1000, min_df=1,
#         ngram_range=(1, 1), norm='l2', preprocessor=None, smooth_idf=True,
#         stop_words='english', strip_accents=None, sublinear_tf=False,
#         token_pattern='(?u)\\b\\w\\w+\\b', tokenizer=None, use_idf=True,
#         vocabulary=None)

# %%
this_vocab = tfidf.vocabulary_

# %%
this_vocab
# Out:
# {'information': 297,
#  'received': 475,
#  'federal': 219,
#  'open': 405,
#  'market': 354,
#  'committee': 105,
#  'met': 367,
#  'january': 311,
#  'indicates': 292,
#  'labor': 325,
#  'remains': 493,
#  'strong': 576,
#  'growth': 253,
#  'economic': 175,
#  'activity': 31,
#  'slowed': 543,
#  'solid': 549,
#  'rate': 466,
#  'fourth': 235,
#  'quarter': 458,
#  'payroll': 419,
#  'employment': 185,
#  'little': 339,
#  'changed': 96,
#  'february': 218,
#  'job': 315,
#  'gains': 239,
#  'average': 65,
#  'recent': 476,
#  'months': 380,
#  'unemployment': 611,
#  'remained': 492,
#  'low': 344,
#  'indicators': 294,
#  'point': 430,
#  'slower': 544,
#  'household': 267,
#  'spending': 553,
#  'business': 89,
#  'fixed': 226,
#  'investment': 305,
#  '12': 1,
#  'month': 379,
#  'basis': 73,
#  'overall': 409,
#  'inflation': 295,
#  'declined': 146,
#  'largely': 329,
#  'result': 500,
#  'lower': 345,
#  'energy': 188,
#  'prices': 444,
#  'items': 308,
#  'food': 230,
# ...

# %%
#generate text from this vocabulary
last_speech = df['text']

# %%
df = pickle.load( open( "mvp_fed_press_rel", "rb" ) )
df.head()
# Out:
#         date                                               text
# 0 2019-01-30  Information received since the Federal Open Ma...
# 1 2019-03-20  Information received since the Federal Open Ma...
# 2 2018-01-31  Information received since the Federal Open Ma...
# 3 2018-03-21  Information received since the Federal Open Ma...
# 4 2018-05-02  Information received since the Federal Open Ma...

# %%
df.sort_values(by=['date'], ascending = False, inplace = True)
df.head()
# Out:
#         date                                               text
# 1 2019-03-20  Information received since the Federal Open Ma...
# 0 2019-01-30  Information received since the Federal Open Ma...
# 9 2018-12-19  Information received since the Federal Open Ma...
# 8 2018-11-08  Information received since the Federal Open Ma...
# 7 2018-09-26  Information received since the Federal Open Ma...

# %%
this_text = df['text'].iloc[0]
this_text
# Out:
# "Information received since the Federal Open Market Committee met in January indicates that the labor market remains strong but that growth of economic activity has slowed from its solid rate in the fourth quarter. Payroll employment was little changed in February, but job gains have been solid, on average, in recent months, and the unemployment rate has remained low. Recent indicators point to slower growth of household spending and business fixed investment in the first quarter. On a 12-month basis, overall inflation has declined, largely as a result of lower energy prices; inflation for items other than food and energy remains near 2 percent. On balance, market-based measures of inflation compensation have remained low in recent months, and survey-based measures of longer-term inflation expectations are little changed.Consistent with its statutory mandate, the Committee seeks to foster maximum employment and price stability. In support of these goals, the Committee decided to main
# ...

# %%
wordcloud = WordCloud(width=400, height =200).generate(this_text)

# Display the generated image:
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()
wordcloud.to_file('last_fed_speech.png')

# %%
wordcloud = WordCloud(width=400, height =200).generate_from_frequencies(this_vocab)

# Display the generated image:
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()
#wordcloud.to_file('last_fed_speech.png')

# %%
word_count=0
for k, v in enumerate(this_vocab):
    print(v)
    word_count += this_vocab[v]
# Out:
# information
# received
# federal
# open
# market
# committee
# met
# january
# indicates
# labor
# remains
# strong
# growth
# economic
# activity
# slowed
# solid
# rate
# fourth
# quarter
# payroll
# employment
# little
# changed
# february
# job
# gains
# average
# recent
# months
# unemployment
# remained
# low
# indicators
# point
# slower
# household
# spending
# business
# fixed
# investment
# 12
# month
# basis
# overall
# inflation
# declined
# largely
# result
# lower
# energy
# prices
# items
# food
# near
# percent
# balance
# based
# measures
# compensation
# survey
# longer
# term
# expectations
# consistent
# statutory
# mandate
# seeks
# foster
# maximum
# price
# stability
# support
# goals
# decided
# maintain
# target
# range
# funds
# continues
# view
# sustained
# expansion
# conditions
# symmetric
# objective
# likely
# outcomes
# light
# global
# financial
# developments
# muted
# pressures
# patient
# determines
# future
# adjustments
# appropriate
# ...

# %%
word_count
# Out:
# 200028
