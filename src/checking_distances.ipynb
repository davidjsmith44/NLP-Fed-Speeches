# %% [markdown]
# # Checking euclidean distances and cosing similarities from NLP_pipeline output

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import pickle

# %%
dist_input = pickle.load( open( "../data/mvp_cosine_sim", "rb" ) )

# %%
cos_last = dist_input['cos_last']
cos_avg_n = dist_input['cos_avg_n']
ed_last = dist_input['ed_last']
ed_avg_n = dist_input['ed_avg_n']
dates = dist_input['dates']

# %%
dist_input.keys()
# Out:
# dict_keys(['cos_last', 'cos_avg_n', 'ed_last', 'ed_avg_n', 'dates'])

# %%
plt.plot(dates, cos_last)

# %%
plt.plot(dates, cos_avg_n)

# %%
plt.plot(dates, ed_last)

# %%
plt.plot(dates, ed_avg_n)

# %%
delta_ed = ed_last - ed_avg_n

# %%
plt.plot(dates, delta_ed)

# %%
np.mean(delta_ed)
# Out:
# 0.0002058659851545623
